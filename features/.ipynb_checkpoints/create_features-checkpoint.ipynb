# %%
import pandas as pd
import os
import codecs
import re
import numpy as np 
import json
import pickle
import matplotlib.pyplot as plt

# %%
sub = "sub05"
path_in = "../trf_results/within/pred_resid/resp_resid_acoustic_8020_speaker_{s}_cv_nb.pickle".format(s =sub)
with open(path_in, "rb") as input_file:
    resp_sub = pickle.load(input_file)

# %%
len(resp_sub[0])
# Out:
# 445

# %%
###Read surprisal and audibility and clean

surprisal_new = pd.read_csv("../surprisal/word_surprisal_gpt_new.csv")

surprisal_new['words'] = surprisal_new['words'].str.replace(",", "")
surprisal_new['words'] = surprisal_new['words'].str.replace(".", "")
surprisal_new['words'] = surprisal_new['words'].str.replace(":", "")
surprisal_new['words'] = surprisal_new['words'].str.replace('"', "")
surprisal_new['words'] = surprisal_new['words'].str.replace('!', "")
surprisal_new = surprisal_new[surprisal_new['words'] != "riegel"]

audibility = pd.read_csv("/data/tu_barchet_cloud/owncloud-gwdg/data_analysis/word_audibility/audibility_words_final_final.csv")
#audibility['word'] = audibility['word'].str.replace('[^\w\s]','', regex=True)

audibility['word'] = audibility['word'].str.replace(",", "")
audibility['word'] = audibility['word'].str.replace(".", "")
audibility['word'] = audibility['word'].str.replace(":", "")
audibility['word'] = audibility['word'].str.replace('"', "")
audibility['word'] = audibility['word'].str.replace('!', "")


surprisal_phone = pd.read_csv("./phone_surprisal_entropy_final1.csv")
#surprisal_phone = pd.read_csv("/data/pt_02917/phone_surprisal_entropy_final.csv")

word_frequency = pd.read_csv("/data/tu_barchet_cloud/owncloud-gwdg/data_analysis/word_frequency/word_frequency_target_lgsubtlex.csv")
word_frequency['frequency']=np.where(word_frequency['word_order'] < 2, np.nan, word_frequency['frequency'])


surprisal_new['surprisal']=np.where(surprisal_new['word_order'] < 2, np.nan, surprisal_new['surprisal'])

#surprisal_phone['phone_entropy']=np.where((surprisal_phone['word_order'] == 1) & (surprisal_phone['phone_num'] == 2), np.nan, surprisal_phone['phone_entropy'])
#surprisal_phone['phone_surprisal']=np.where((surprisal_phone['word_order'] == 1) & (surprisal_phone['phone_num'] == 2), np.nan, surprisal_phone['phone_surprisal'])




audibility_phone = pd.read_csv("/data/tu_barchet_cloud/owncloud-gwdg/data_analysis/word_audibility/audibility_phones_final_final.csv")

audibility_phone['words'] = audibility_phone['words'].str.replace(",", "")
audibility_phone['words'] = audibility_phone['words'].str.replace(".", "")
audibility_phone['words'] = audibility_phone['words'].str.replace(":", "")
audibility_phone['words'] = audibility_phone['words'].str.replace('"', "")
audibility_phone['words'] = audibility_phone['words'].str.replace('!', "")


#audibility_phone['words'] = audibility_phone['words'].str.replace('[^\w\s]','', regex=True)

# %%
surprisal_phone[['phone_surprisal', 'phone_entropy']].corr()
# Out:
#                  phone_surprisal  phone_entropy
# phone_surprisal         1.000000       0.255979
# phone_entropy           0.255979       1.000000

# %%
surprisal_new[['surprisal', 'entropy']].corr()
# Out:
#            surprisal   entropy
# surprisal   1.000000  0.649255
# entropy     0.649255  1.000000

# %%
surprisal_new[surprisal_new['id'] == 58]
# Out:
#      Unnamed: 0       words  surprisal    entropy  id  word_order  \
# 330         330         Der        NaN   8.896342  58           1
# 331         331       gelbe  13.162035  11.863558  58           2
# 332         332  Küchenofen  25.982122  17.693862  58           3
# 333         333       sorgt   7.042069   7.074579  58           4
# 334         334         für   1.132430   3.760792  58           5
# 335         335       Wärme   4.163781   7.382320  58           6
#
#      surprisal_new
# 330            NaN
# 331      13.162035
# 332      25.982122
# 333       7.042069
# 334       1.132430
# 335       4.163781

# %%
## Load subject responses
sent = []
names = []
part = []
sub = []

outpath = "/data/pt_02917/transcriptions_final/"

for path, subdirs, files in os.walk(outpath):
    for name in files:
        if name.endswith(".lab") and name.startswith("sub") or name.startswith("41") or name.startswith("67"):

                #load all audios
            infile = os.path.join(path, name)

            f = codecs.open(infile, "r", "utf-8-sig")
            lines = f.read()

            lines = lines.replace("ï»¿ ", "")
            if name.startswith("41"):
                sub.append("sub41")
            elif name.startswith("67"):
                sub.append("sub67")
            else:
                sub.append(name[0:5])


            sent.append(lines)
            names.append(name)

sub_result = pd.DataFrame(zip(names, sent), columns = ['name', 'resp'])           
sub_result['target_id'] = sub_result['name'].str[-7:-4]
sub_result['subject'] = sub

sub_result['target_id'] = pd.to_numeric(sub_result['target_id'])

# %%
f="surprisal"
with open("./input_final/{f}_target_final_yo_125.pickle".format(f = f), "rb") as input_file:
    feat = pickle.load(input_file)

f="surprisal"
with open("./input_final/{f}_target_final_yo.pickle".format(f = f), "rb") as input_file:
    feato = pickle.load(input_file)

# %%
subject = "sub05"
out_name = "ling_{sub}_nb_resid_within_withent_ws.pickle".format( sub = subject)
trfp = "../trf_input/" + subject 


path_out = "../trf_input/" + subject + "/" + out_name
with open(path_out, "rb") as output_file:
    o=pickle.load(output_file)

subject = "sub05"
out_name = "ling_{sub}_nb_resid_within_withent.pickle".format( sub = subject)
trfp = "../trf_input/" + subject 


path_out = "../trf_input/" + subject + "/" + out_name
with open(path_out, "rb") as output_file:
    o1=pickle.load(output_file)

# %%
plt.plot(o[0][:,0])
plt.plot(o1[0][:,0])

# %%
plt.plot(feat[6])
plt.plot(feato[6])

# %%
##Load subject experiment files
import scipy.stats as stats
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()



##For all pilot subjects
subs = ['sub05', 'sub06', 'sub07', 'sub08', 'sub09', 'sub10', 'sub11', 'sub12', 'sub13', 'sub14', 'sub15', 'sub16', 
        'sub18', 'sub19', 'sub20', 'sub21', 'sub22', 'sub23', 'sub24', 'sub25', 'sub26', 'sub27', 'sub28', 'sub29', 
       'sub30', 'sub31', 'sub32', 'sub33', 'sub34', 'sub35', 'sub36', 'sub37', 'sub38', 'sub39', 'sub40', 'sub41', 
       'sub42', 'sub43', 'sub44', 'sub45', 'sub46', 'sub47', 'sub48', 'sub49', 'sub50', 'sub51', 'sub52', 'sub53', 
       'sub54', 'sub55', 'sub56', 'sub57', 'sub58', 'sub59', 'sub60', 'sub61', 'sub62', 'sub63', 'sub64', 'sub65', 'sub66', 
       'sub67', 'sub68', 'sub69', 'sub70',  'sub72']

#subs = ['sub05']
subs_fulldf = []
for sub in subs: 
    subnum = sub[3:]
    subnum = int(subnum)
    if subnum != 69:
        path_sub = "/data/pt_02917/data/{s}/main_exp/{s}_mainexp.csv".format(s = sub)

    elif subnum == 69:
        path_sub = "/data/pt_02917/data/sub69/main_exp/sub69_complete.csv"

    df = pd.read_csv(path_sub, sep = ";")

    if subnum == 41:
        df['subject'] = "sub41"
    elif subnum == 67:
        df['subject'] = "sub67"
    

    ##Create one row for every word 
    df = df.assign(sentence=df['sentence'].str.split(' ')).explode('sentence')
    #Create a column for the word order (important for merging) 
    w_order = []
    for sentence_id in df['target'].unique():
        sent_w = df[df['target']== sentence_id]
        wo = 1
        
        for i,r in sent_w.iterrows():
            w_order.append(wo)
            wo = wo + 1
    
    df['word_order'] = w_order
    ##Make sure that all letters are correctly represented
    df['sentence'] = df['sentence'].str.replace("Ãľ", "Ü")
    df['sentence'] = df['sentence'].str.replace("Ã¼", "ü")
    df['sentence'] = df['sentence'].str.replace("Ã¶", "ö")
    df['sentence'] = df['sentence'].str.replace("Ã¤", "ä")
    df['sentence'] = df['sentence'].str.replace("ÃŁ", "ß")
    df['sentence'] = df['sentence'].str.replace("ÃĦ", "Ä")
    df['sentence'] = df['sentence'].str.replace("Ãĸ", "Ö")
    #Remove Punctuation
    df['sentence'] = df['sentence'].str.replace(",", "")
    df['sentence'] = df['sentence'].str.replace(".", "")
    df['sentence'] = df['sentence'].str.replace(":", "")
    df['sentence'] = df['sentence'].str.replace('"', "")
    df['sentence'] = df['sentence'].str.replace('!', "")
    
   # df['sentence'] = df['sentence'].str.replace('[^\w\s]','', regex=True)


    #For merging
    df['target_id'] = df['target'].str[0:3]
    df['target_id'] = pd.to_numeric(df['target_id'])


    df_full = pd.merge(df, surprisal_new, left_on = [ 'target_id', 'word_order'], right_on = [ 'id', 'word_order'], suffixes=('', '_y'))

    
    df_full.drop(['id', 'Unnamed: 0', 'words'], axis=1, inplace=True)
    df_full['words'] = df_full['sentence']
    df_full.drop(['sentence'], axis=1, inplace=True)
    

    df_full1 = pd.merge(df_full, audibility, left_on = [ 'target_id', 'word_order'], right_on = ['ids',  'word_order'])
    df_full1.drop(['Unnamed: 0', 'word', 'ids', 'filename'], axis=1, inplace=True)


    df_full2 = pd.merge(df_full1, word_frequency, left_on = ['target_id', 'word_order'], right_on = ['id',  'word_order'])
    ##Checking accuracy = Which words from the actual sentences are in the response

    acc = []
    misheard = []
    start_time = []
    end_time = []

    for target_id in df_full2['target_id'].unique():
        sent_df = df_full2.loc[df_full1['target_id'] == target_id]
        sub = sent_df.iloc[0,0]
    
        
        sub_responses = sub_result[sub_result['subject'] == sub]
        trial_resp = sub_responses[sub_responses['target_id'] == target_id]

        
        last_double_word = []

        if len(trial_resp) > 0:
            
            for i1,r1 in trial_resp.iterrows():
                resp = r1['resp']
        
        else:
            resp = ""

        resp = resp.lower()

        if resp == "nicht verstanden" or resp == "nichts verstanden":
            resp = ""


        resp = resp.replace('portraits', 'portäts')
        resp = resp.replace('brötchen backen', 'brötchenbacken')
        resp = resp.replace('skilaufen', 'ski laufen')
        resp = resp.replace('lös', 'löst')
        resp = resp.replace('einst weilen', 'einstweilen')
        resp = resp.replace('asthma-anfälle', 'asthmaanfälle')
        resp = resp.replace('12', 'zwölf')
        resp = resp.replace('umgehungsstrasse', 'umgehungsstraße')
        resp = resp.replace('30', 'dreißig')
        resp = resp.replace('heuaufen', 'heuhaufen')
        resp = resp.replace('8', 'acht')
        resp = resp.replace('2', 'zwei')
        resp = resp.replace('5', 'fünf')
        resp = resp.replace('flug', 'pflug')
        resp = resp.replace('1000', 'tausend')

        resp = resp.replace('gibt es', 'gibts')
        resp = resp.replace('über dem', 'überm')
        resp = resp.replace('Rauhreif', 'Raureif')
        
        resp = resp.replace('gewehr', 'gewähr')
        resp = resp.replace('oberleutnants', 'oberstleutnants')
        resp = resp.replace('bergs', 'berges')
        resp = resp.replace('bergesteiger', 'bergsteiger')

        resp = re.sub(r'[^\w\s]','', resp) 
        resp_w = resp.split(" ")

        
        
    
        for i,r in sent_df.iterrows():
            r['words'] = r['words'].lower()
            r['words'] = re.sub(r'[^\w\s]','', r['words']) 
    

            acc_t = any(r['words'] == w for w in resp_w)

            
            acc.append(acc_t)
       


    df_full2['acc'] = acc

    df_full2['surprisal']=np.where(df_full2['word_order'] < 2, np.nan, df_full2['surprisal'])
    df_full2['frequency']=np.where(df_full2['word_order'] < 2, np.nan, df_full2['frequency'])
    df_full2['entropy']=np.where(df_full2['word_order'] < 2, np.nan, df_full2['entropy'])

    df_phone = pd.merge(df_full2, audibility_phone, left_on = ['words', 'target_id', 'word_order'], right_on = ['words', 'ids', 'wordnum'])
        
    df_phone['audibility_word'] = df_phone['audibility_x']
    df_phone['audibility_phone'] = df_phone['audibility_y']

    df_phone.drop([ 'ids',  'filename', 'audibility_x', 'audibility_y'], axis=1, inplace=True)

    df_phone['words'] = df_phone['words'].str.lower()
   
    df_phone['phone_num']=df_phone.groupby(['words', 'target_id', 'word_order']).cumcount()+1

    df_full = pd.merge(df_phone, surprisal_phone, left_on = ['phone', 'words','target_id', 'phone_num'], right_on = ['phone','word', 'target_id', 'phone_num'])

    ##For saving (behav analysis)
    subs_fulldf.append(df_full2)


    ## TRF Feature creation (upsampling) ######
    ###Standardize the features


    
    df_full['phone_surprisal'] = min_max_scaler.fit_transform(df_full[['phone_surprisal']])
    df_full['phone_entropy'] = min_max_scaler.fit_transform(df_full[['phone_entropy']])
    df_full['surprisal'] = min_max_scaler.fit_transform(df_full[['surprisal']])    
    df_full['frequency'] = min_max_scaler.fit_transform(df_full[['frequency']])
    df_full['entropy'] = min_max_scaler.fit_transform(df_full[['entropy']])

    df_full['surprisal']=np.where(df_full['wordnum'] < 2, np.nan, df_full['surprisal'])
    df_full['frequency']=np.where(df_full['wordnum'] < 2, np.nan, df_full['frequency'])
    df_full['entropy']=np.where(df_full['wordnum'] < 2, np.nan, df_full['entropy'])

    ###Correct and incorrect ids
    id_cor = []
    id_f = []
    idb = []


    df_full_nb = df_full.copy()
    for t in df_full_nb['target'].unique():
        df = df_full_nb[df_full_nb['target'] == t]
        if all(df['acc']):
            id_cor.append(df.iloc[0]['target_id'])
        else:
            id_f.append(df.iloc[0]['target_id'])


        corn = "/data/pt_02917/trf_input/stim_cor_{sub}_nb.pickle".format(sub = sub)
       # with open(corn, "wb") as output_file:
        #    pickle.dump(id_cor, output_file)

        incorn = "/data/pt_02917/trf_input/stim_incor_{sub}_nb.pickle".format(sub = sub)
      #  with open(incorn, "wb") as output_file:
        #    pickle.dump(id_f, output_file)

        if df['db_cond'].iloc[0] == 10:
            idb.append(df.iloc[0]['target_id'])

        bn = "/data/pt_02917/trf_input/stim_bs_{sub}.pickle".format(sub = sub)
       # with open(bn, "wb") as output_file:
       #     pickle.dump(idb, output_file)
            




df_full_con = pd.concat(subs_fulldf)
#df_full_con.to_csv("../statistical_analysis/behavdat_new_we_ws.csv", sep = ";")

# %%
sub = "sub05"
corn = "/data/pt_02917/trf_input/stim_cor_{sub}_nb.pickle".format(sub = sub)
with open(corn, "rb") as output_file:
    id_cor = pickle.load(output_file)

# %%
df_full[['surprisal', 'entropy']].corr()
# Out:
#            surprisal   entropy
# surprisal   1.000000  0.598824
# entropy     0.598824  1.000000

# %%
feats = ['surprisal', 'frequency','entropy', 'phone_surprisal', 'phone_entropy', 'word_onset', 'phone_onset']
#feats = ['surprisal']

for feat in feats:
    upsamp = []

        
    for t,dfsent in df_full.groupby('target', sort = False):
        
        # Parameters
        sampling_rate = 128  # Hz
        duration = dfsent['end_s_x'].max() # add 1 sec buffer (or use known total duration)
        n_samples = int(np.ceil(duration * sampling_rate))
        
        # Initialize array with zeros
        signal = np.zeros(n_samples)

        if 'phone' in feat:
            onset_samples = (dfsent['start_s_y'] * sampling_rate).round().astype(int)
        else:
            # Convert onset times to sample indices
            onset_samples = (dfsent['start_s_x'] * sampling_rate).round().astype(int)

     
        
        if 'onset' in feat:
            signal[onset_samples] = 1
        else:
        
            # Insert values into the signal at the onset sample indices
            signal[onset_samples] = dfsent[feat].values
        signal = np.nan_to_num(signal)
    
        upsamp.append(signal)

        

        

        with open('./input_final/{f}_target_final_yo_ws.pickle'.format(f = feat), 'wb') as o:
            pickle.dump(upsamp, o)

# %%
df_full
# Out:
#      subject  trialnum gender_follow   target   distractor  \
# 0      sub72         1          male  151.wav  dis_264.wav
# 1      sub72         1          male  151.wav  dis_264.wav
# 2      sub72         1          male  151.wav  dis_264.wav
# 3      sub72         1          male  151.wav  dis_264.wav
# 4      sub72         1          male  151.wav  dis_264.wav
# ...      ...       ...           ...      ...          ...
# 7049   sub72       240          male  007.wav  dis_062.wav
# 7050   sub72       240          male  007.wav  dis_062.wav
# 7051   sub72       240          male  007.wav  dis_062.wav
# 7052   sub72       240          male  007.wav  dis_062.wav
# 7053   sub72       240          male  007.wav  dis_062.wav
#
#                                     distractor_sentence     srt_db   srt_snr  \
# 0      Ein neues Gesetz zum Datenschutz tritt in Kraft. -15.625787 -7.812893
# 1      Ein neues Gesetz zum Datenschutz tritt in Kraft. -15.625787 -7.812893
# 2      Ein neues Gesetz zum Datenschutz tritt in Kraft. -15.625787 -7.812893
# 3      Ein neues Gesetz zum Datenschutz tritt in Kraft. -15.625787 -7.812893
# 4      Ein neues Gesetz zum Datenschutz tritt in Kraft. -15.625787 -7.812893
# ...                                                 ...        ...       ...
# 7049  Ein charmantes Lächeln erhellt das Gesicht des... -15.625787 -7.812893
# 7050  Ein charmantes Lächeln erhellt das Gesicht des... -15.625787 -7.812893
# 7051  Ein charmantes Lächeln erhellt das Gesicht des... -15.625787 -7.812893
# 7052  Ein charmantes Lächeln erhellt das Gesicht des... -15.625787 -7.812893
# 7053  Ein charmantes Lächeln erhellt das Gesicht des... -15.625787 -7.812893
#
#       db_cond  trial_start  ...  start_s_y   end_s_y  audibility_word  \
# 0           0  6084.806129  ...    0.00000  0.037098         0.687500
# 1           0  6084.806129  ...    0.03712  0.107098         0.687500
# 2           0  6084.806129  ...    0.10712  0.177098         0.687500
# 3           0  6084.806129  ...    0.17712  0.227098         0.394676
# 4           0  6084.806129  ...    0.22712  0.257098         0.394676
# ...       ...          ...  ...        ...       ...              ...
# 7049        1  8950.102810  ...    2.58712  2.647098         0.377516
# 7050        1  8950.102810  ...    2.64712  2.727098         0.377516
# 7051        1  8950.102810  ...    2.72712  2.847098         0.377516
# 7052        1  8950.102810  ...    2.84712  3.097098         0.377516
# 7053        1  8950.102810  ...    3.09712  3.277098         0.377516
#
#      audibility_phone  phone_num  Unnamed: 0  phone_surprisal  phone_entropy  \
# 0            0.114062          1        1517              NaN            NaN
# 1            0.820312          2        1518         0.205903       0.405365
# 2            0.972222          3        1519         0.109170       0.159317
# 3            0.203125          1        1520              NaN            NaN
# 4            0.658203          2        1521         0.229350       0.131299
# ...               ...        ...         ...              ...            ...
# 7049         0.643555          4         515         0.187825       0.002473
# 7050         0.577344          5         516         0.079180       0.001362
# 7051         0.390625          6         517         0.172627       0.000275
# 7052         0.437012          7         518         0.049219       0.000160
# 7053         0.018342          8         519         0.000000       0.000160
#
#             word_y word_order_y
# 0               er            1
# 1               er            1
# 2               er            1
# 3             wird            2
# 4             wird            2
# ...            ...          ...
# 7049  sonnenschein            5
# 7050  sonnenschein            5
# 7051  sonnenschein            5
# 7052  sonnenschein            5
# 7053  sonnenschein            5
#
# [7054 rows x 41 columns]

# %%
#Save stimulus numbers
stimnum = df_full['target_id'].unique().tolist()
with open('./input_final/stimnum_target.pickle', 'wb') as o:
    pickle.dump(stimnum, o)

# %% [markdown]
# ## Distractor

# %%
new = pd.read_csv("/data/pt_02917/surprisal/word_surprisal_gpt_dis2.csv")
old = pd.read_csv("/data/pt_02917/surprisal/word_surprisal_entropy_dis_witheos.csv")

# %%
word_surprisal
# Out:
#       Unnamed: 0       words  surprisal    entropy       id  word_order  \
# 0              0         Das  18.880919   8.896342  dis_001           1
# 1              1        Haus   7.607473  10.476741  dis_001           2
# 2              2       neben   9.931495   7.517183  dis_001           3
# 3              3         dem   1.228942   3.027467  dis_001           4
# 4              4  Leuchtturm  12.112391  10.609597  dis_001           5
# ...          ...         ...        ...        ...      ...         ...
# 2660        2660         ich   0.109664   0.919597  dis_290           4
# 2661        2661    meistens  10.902640   8.093947  dis_290           5
# 2662        2662    einfache  12.384313   8.364922  dis_290           6
# 2663        2663    Gerichte   0.850659   4.516953  dis_290           7
# 2664        2664      riegel  22.580070   3.991024  dis_290           8
#
#       surprisal_new
# 0               NaN
# 1          7.607473
# 2          9.931495
# 3          1.228942
# 4         12.112391
# ...             ...
# 2660       0.109664
# 2661      10.902640
# 2662      12.384313
# 2663       0.850659
# 2664      22.580070
#
# [2665 rows x 7 columns]

# %%
import pandas as pd

word_surprisal = pd.read_csv("/data/pt_02917/surprisal/word_surprisal_entropy_gpt_dis2.csv")
#phone_surprisal = pd.read_csv("/data/pt_02917/phone_surprisal_entropy_distractors_final.csv")
#
phone_surprisal = pd.read_csv("./phone_surprisal_entropy_final1_dis.csv")

directory = '/data/tu_barchet_cloud/owncloud-gwdg/data_analysis/word_audibility/word_seg_distractors/'

sent_id = []
words = []
start = []
end = []
word_order = []

for root,dirs,files in os.walk(directory):
    for file in files:
        if file.endswith(".csv"):
            idx = file[:-4]
            p = os.path.join(directory, file)
            f=pd.read_csv(p, sep = ";")
            
            ##Remove silence in the beginning and end
            f = f.drop(f.loc[(f.MAU == "(...)")].index)
            
            f = f.drop(f.loc[(f.MAU.isnull())].index)

            f = f.drop(f.loc[f.TOKEN == -1].index)
    
            words_sent = list(f['TOKEN'].unique())
            wo = 1
            
            for w in words_sent:
                f_w = f.loc[f['TOKEN'] == w]
                word_start = f_w.iloc[0,0]
                word_end = f_w.iloc[-1,0] + f_w.iloc[-1,1]
                word = f_w.iloc[0,5]
    
                word_order.append(wo)
                wo = wo + 1
                
                sent_id.append(idx)
                #print(idx)
                words.append(word)
                start.append(word_start)
                end.append(word_end)

sent_words = pd.DataFrame(zip(sent_id, words, start, end, word_order), columns = ['id', 'word', 'start', 'end', 'word_order'])

##Calculate seconds
sent_words['start_s'] = sent_words['start']/44100
sent_words['end_s'] = sent_words['end']/44100


merge1 = pd.merge(sent_words, word_surprisal, on = ['id', 'word_order'])
merge1.drop(['words', 'Unnamed: 0'], axis = 1, inplace = True)



targets_complete = pd.read_csv('/data/pt_02917/behavior_stimuli/target_distractor_final_final.csv', sep = ";")

directory = '/data/tu_barchet_cloud/owncloud-gwdg/data_analysis/word_audibility/word_seg_distractors/'


sent_id = []
words = []
phones = []
start = []
end = []
word_order = []
wordnum = []
syl_nums = []
syls = []

for root,dirs,files in os.walk(directory):
    for file in files:
        if file[:7] in list(targets_complete['distractor'].str[:7]):

            p = os.path.join(directory, file)
            if p.endswith(".csv"):
                f=pd.read_csv(p, sep = ";")
            
                ##Remove silence in the beginning and end
                f = f.drop(f.loc[(f.MAU == "(...)")].index)
                f = f.drop(f.loc[f.TOKEN == -1].index)
                f = f.drop(f.loc[(f.MAU.isnull())].index)

                f = f.reset_index(drop=True)
                wo = 1
        
                syl_add = ""
                syl_num = 1
                syl_count = 1
                
                for i,p1 in f.iterrows():
                    f_w = p1
                    phone_start = p1.iloc[0]
                    phone_end = p1.iloc[0] + p1.iloc[1]
                    phone = p1.iloc[3]
                    word = p1.iloc[5]
                    numw = int(p1.iloc[2])+1
        
                    word_order.append(wo)
                    wo = wo + 1
        
    
        
                    
                    sent_id.append(file[:7])
                    phones.append(phone)
                    words.append(word)
                    wordnum.append(numw)
        
                    start.append(phone_start)
                    end.append(phone_end)
                


sent_words = pd.DataFrame(zip(sent_id, words, phones, start, end, word_order, wordnum), columns = ['id', 'words', 'phone', 'start', 'end', 'phone_order', 'wordnum'])

##Calculate seconds
sent_words['start_s'] = sent_words['start']/44100
sent_words['end_s'] = sent_words['end']/44100

sent_words['phone_num'] = sent_words.groupby(['id', 'words', 'wordnum']).cumcount()+1


merge2 = pd.merge(sent_words, phone_surprisal, left_on = ['id', 'wordnum', 'phone_num'], right_on = ['id', 'word_order', 'phone_num'])
merge2.drop(['words', 'Unnamed: 0',  'wordnum', 'phone_order'], axis = 1, inplace = True)


merge_surpdis = pd.merge(merge1, merge2, on = ['id', 'word_order'])

freq_dis = pd.read_csv("/data/tu_barchet_cloud/owncloud-gwdg/data_analysis/word_frequency/word_frequency_distractor_lgsubtlex.csv")


merge_surpdis_freq = pd.merge(merge_surpdis, freq_dis, on = ['id', 'word_order'])

merge_surpdis_freq['surprisal']=np.where(merge_surpdis_freq['word_order'] == 1, np.nan, merge_surpdis_freq['surprisal'])
merge_surpdis_freq['frequency']=np.where(merge_surpdis_freq['word_order'] == 1, np.nan, merge_surpdis_freq['frequency'])
merge_surpdis_freq['entropy']=np.where(merge_surpdis_freq['word_order'] == 1, np.nan, merge_surpdis_freq['entropy'])

from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()


import scipy.stats as stats

merge_surpdis_freq['surprisal'] = min_max_scaler.fit_transform(merge_surpdis_freq[['surprisal']])
merge_surpdis_freq['phone_surprisal'] = min_max_scaler.fit_transform(merge_surpdis_freq[['phone_surprisal']])
merge_surpdis_freq['phone_entropy'] = min_max_scaler.fit_transform(merge_surpdis_freq[['phone_entropy']])
merge_surpdis_freq['frequency'] = min_max_scaler.fit_transform(merge_surpdis_freq[['frequency']])
merge_surpdis_freq['entropy']=min_max_scaler.fit_transform(merge_surpdis_freq[['entropy']])

# %%
merge_surpdis_freq

# %%
merge_surpdis_freq
# Out:
#             id word_x  start_x   end_x  word_order  start_s_x   end_s_x  \
# 0      dis_283    Ein     1637   11779           1    0.03712  0.267098
# 1      dis_283    Ein     1637   11779           1    0.03712  0.267098
# 2      dis_283    Ein     1637   11779           1    0.03712  0.267098
# 3      dis_283  Blick    11780   25450           2    0.26712  0.577098
# 4      dis_283  Blick    11780   25450           2    0.26712  0.577098
# ...        ...    ...      ...     ...         ...        ...       ...
# 10568  dis_174  ihrer   130850  146725           7    2.96712  3.327098
# 10569  dis_174  Reise   146726  178918           8    3.32712  4.057098
# 10570  dis_174  Reise   146726  178918           8    3.32712  4.057098
# 10571  dis_174  Reise   146726  178918           8    3.32712  4.057098
# 10572  dis_174  Reise   146726  178918           8    3.32712  4.057098
#
#        surprisal    entropy  surprisal_new  ...   end_s_y phone_num  phone_y  \
# 0            NaN   8.896350      18.193531  ...  0.087098         1        ʔ
# 1            NaN   8.896350      18.193531  ...  0.187098         2       aɪ
# 2            NaN   8.896350      18.193531  ...  0.267098         3        n
# 3       0.226900  11.972282       8.932570  ...  0.347098         1        b
# 4       0.226900  11.972282       8.932570  ...  0.397098         2        l
# ...          ...        ...            ...  ...       ...       ...      ...
# 10568   0.233215   2.544165       9.180891  ...  3.327098         4        ɐ
# 10569   0.089944   8.391256       3.547372  ...  3.387098         1        r
# 10570   0.089944   8.391256       3.547372  ...  3.677098         2       aɪ
# 10571   0.089944   8.391256       3.547372  ...  3.807098         3        z
# 10572   0.089944   8.391256       3.547372  ...  4.057098         4        ə
#
#        phone_surprisal  phone_entropy  ent_first  word_y Unnamed: 0   word  \
# 0                  NaN            NaN   6.934282     ein       1759    ein
# 1             0.157716       0.277940        NaN     ein       1759    ein
# 2             0.003104       0.258330        NaN     ein       1759    ein
# 3                  NaN            NaN   8.384966   blick       1760  blick
# 4             0.189118       0.041887        NaN   blick       1760  blick
# ...                ...            ...        ...     ...        ...    ...
# 10568         0.140811       0.003546        NaN   ihrer        290  ihrer
# 10569              NaN            NaN   8.696395   reise        291  reise
# 10570         0.148728       0.027709        NaN   reise        291  reise
# 10571         0.172306       0.002411        NaN   reise        291  reise
# 10572         0.000656       0.002378        NaN   reise        291  reise
#
#        frequency
# 0       0.888850
# 1       0.888850
# 2       0.888850
# 3       0.513232
# 4       0.513232
# ...          ...
# 10568   0.617149
# 10569   0.523818
# 10570   0.523818
# 10571   0.523818
# 10572   0.523818
#
# [10573 rows x 25 columns]

# %%
feats = ['surprisal', 'frequency','entropy', 'phone_surprisal', 'phone_entropy', 'word_onset', 'phone_onset']

for feat in feats:
    upsamp = []

        
    for t,dfsent in merge_surpdis_freq.groupby('id', sort = False):
        
        # Parameters
        sampling_rate = 128  # Hz
        duration = dfsent['end_s_y'].max()   
        n_samples = int(np.ceil(duration * sampling_rate))
        
        # Initialize array with zeros
        signal = np.zeros(n_samples)

        if 'phone' in feat:
            onset_samples = (dfsent['start_s_y'] * sampling_rate).round().astype(int)
        else:
            # Convert onset times to sample indices
            onset_samples = (dfsent['start_s_x'] * sampling_rate).round().astype(int)

        
        if 'onset' in feat:
            signal[onset_samples] = 1
        else:
        
            # Insert values into the signal at the onset sample indices
            signal[onset_samples] = dfsent[feat].values
        signal = np.nan_to_num(signal)
    
        upsamp.append(signal)

        

        

        with open('./input_final/{f}_dis_final_yo.pickle'.format(f = feat), 'wb') as o:
            pickle.dump(upsamp, o)

# %%
t
# Out:
# 'dis_289'

# %%
#Save stimulus numbers
stimnum = merge_surpdis_freq['id'].unique().tolist()
with open('./input_final/stimnum_dis.pickle', 'wb') as o:
    pickle.dump(stimnum, o)

# %%
stimnum
# Out:
# ['dis_283',
#  'dis_145',
#  'dis_252',
#  'dis_139',
#  'dis_061',
#  'dis_066',
#  'dis_284',
#  'dis_142',
#  'dis_193',
#  'dis_255',
#  'dis_130',
#  'dis_227',
#  'dis_068',
#  'dis_014',
#  'dis_013',
#  'dis_137',
#  'dis_269',
#  'dis_026',
#  'dis_215',
#  'dis_102',
#  'dis_105',
#  'dis_179',
#  'dis_053',
#  'dis_082',
#  'dis_260',
#  'dis_177',
#  'dis_267',
#  'dis_170',
#  'dis_028',
#  'dis_054',
#  'dis_161',
#  'dis_276',
#  'dis_094',
#  'dis_045',
#  'dis_042',
#  'dis_166',
#  'dis_271',
#  'dis_114',
#  'dis_203',
#  'dis_030',
#  'dis_168',
#  'dis_037',
#  'dis_278',
#  'dis_204',
#  'dis_231',
#  'dis_126',
#  'dis_121',
#  'dis_005',
#  'dis_077',
#  'dis_238',
#  'dis_182',
#  'dis_244',
#  'dis_243',
#  'dis_154',
#  'dis_070',
#  'dis_266',
#  'dis_171',
#  'dis_029',
#  'dis_055',
#  'dis_084',
#  'dis_052',
#  'dis_083',
#  'dis_176',
#  'dis_213',
#  'dis_104',
#  'dis_178',
#  'dis_020',
#  'dis_268',
#  'dis_027',
#  'dis_214',
#  'dis_103',
#  'dis_012',
#  'dis_136',
#  'dis_221',
#  'dis_226',
#  'dis_069',
#  'dis_015',
#  'dis_228',
#  'dis_067',
#  'dis_143',
#  'dis_192',
#  'dis_254',
#  'dis_282',
#  'dis_144',
#  'dis_195',
#  'dis_138',
#  'dis_060',
#  'dis_184',
#  'dis_242',
#  'dis_155',
#  'dis_071',
#  'dis_076',
#  'dis_239',
#  'dis_183',
#  'dis_245',
#  'dis_078',
#  'dis_237',
#  'dis_120',
#  'dis_004',
#  'dis_003',
#  'dis_230',
#  'dis_036',
#  'dis_279',
#  'dis_112',
#  'dis_205',
#  'dis_115',
#  'dis_202',
#  'dis_031',
#  'dis_169',
#  'dis_043',
#  'dis_167',
#  'dis_270',
#  'dis_038',
#  'dis_160',
#  'dis_277',
#  'dis_095',
#  'dis_044',
#  'dis_075',
#  'dis_009',
#  'dis_180',
#  'dis_151',
#  'dis_241',
#  'dis_187',
#  'dis_156',
#  'dis_072',
#  'dis_189',
#  'dis_158',
#  'dis_233',
#  'dis_234',
#  'dis_123',
#  'dis_007',
#  'dis_116',
#  'dis_201',
#  'dis_032',
#  'dis_035',
#  'dis_098',
#  'dis_049',
#  'dis_111',
#  'dis_206',
#  'dis_163',
#  'dis_274',
#  'dis_047',
#  'dis_208',
#  'dis_091',
#  'dis_040',
#  'dis_164',
#  'dis_109',
#  'dis_051',
#  'dis_080',
#  'dis_262',
#  'dis_175',
#  'dis_265',
#  'dis_219',
#  'dis_056',
#  'dis_087',
#  'dis_217',
#  'dis_100',
#  'dis_058',
#  'dis_089',
#  'dis_210',
#  'dis_107',
#  'dis_023',
#  'dis_132',
#  'dis_225',
#  'dis_288',
#  'dis_259',
#  'dis_016',
#  'dis_149',
#  'dis_198',
#  'dis_011',
#  'dis_135',
#  'dis_222',
#  'dis_147',
#  'dis_281',
#  'dis_196',
#  'dis_063',
#  'dis_064',
#  'dis_140',
#  'dis_286',
#  'dis_257',
#  'dis_018',
#  'dis_090',
#  'dis_041',
#  'dis_162',
#  'dis_097',
#  'dis_046',
#  'dis_209',
#  'dis_034',
#  'dis_048',
#  'dis_207',
#  'dis_117',
#  'dis_200',
#  'dis_033',
#  'dis_235',
#  'dis_122',
#  'dis_006',
#  'dis_001',
#  'dis_188',
#  'dis_159',
#  'dis_232',
#  'dis_240',
#  'dis_186',
#  'dis_157',
#  'dis_073',
#  'dis_074',
#  'dis_008',
#  'dis_247',
#  'dis_150',
#  'dis_141',
#  'dis_287',
#  'dis_256',
#  'dis_190',
#  'dis_146',
#  'dis_280',
#  'dis_251',
#  'dis_197',
#  'dis_062',
#  'dis_148',
#  'dis_199',
#  'dis_010',
#  'dis_134',
#  'dis_133',
#  'dis_224',
#  'dis_289',
#  'dis_258',
#  'dis_017',
#  'dis_106',
#  'dis_022',
#  'dis_216',
#  'dis_059',
#  'dis_088',
#  'dis_264',
#  'dis_173',
#  'dis_218',
#  'dis_057',
#  'dis_086',
#  'dis_050',
#  'dis_081',
#  'dis_263',
#  'dis_174']

# %% [markdown]
# ## Envelopes and rates

# %%
##Envelopes (this has to be done for every participant individually) 
from scipy.signal import butter, filtfilt, find_peaks, resample
import librosa 
import naplib
import matplotlib.pyplot as plt
import logging
import numpy as np
import pandas as pd
import scipy
import pickle
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()


logging.getLogger("naplib").setLevel(logging.FATAL)

subs = [   'sub05']

for sub in subs:
    subnum = sub[3:]
    subnum = int(subnum)
    if subnum != 41 and subnum != 69:
        path_sub = "/data/pt_02917/data/{s}/main_exp/{s}_mainexp.csv".format(s = sub)
    elif subnum == 41:
        path_sub = "/data/pt_02917/data/sub41/main_exp/sub41_mainexp.csv"
    elif subnum == 69:
        path_sub = "/data/pt_02917/data/sub69/main_exp/sub69_complete.csv"
 
    df = pd.read_csv(path_sub, sep = ";")

    if subnum == 41:
        df['subject'] = "sub41"
    elif subnum == 67:
        df['subject'] = "sub67"


    target_path = "/data/pt_02917/behavior_stimuli/targets_final_norm/"
    distractor_path = "/data/pt_02917/behavior_stimuli/distractors_new_clean/"
    
    envelopes_target = []
    rates_target = []
    spec_target = []
    
    spec_dis = []
    envelopes_dis = []
    rates_dis = []
    #subdat = subdat.sort_values(by = "target")
    
    cutoff=20.
    comp_factor=1./3
    resample=128
    band=[1,10]
    from scipy.stats import zscore
    for i,r in df.iterrows():
    
        target, sr = librosa.load(target_path + r['target'], sr = 44100)
        distractor, sr = librosa.load(distractor_path + r['distractor'], sr = 44100)
    
    
       # zero pad the target
        zer = np.array([0]*22050)
        y1_sil = np.concatenate((zer,target))
        
        zer2 = np.array([0]*(len(distractor)-len(y1_sil)))
        target_pad = np.concatenate((y1_sil, zer2))
    
        amp_target = r['srt_db'] + r['db_cond']
       
        ###Calculate the spectrogram 
        spec= naplib.features.auditory_spectrogram(target_pad, sr)
    
        # Extract the envelope by taking the mean over frequencies
        env = np.mean(spec, axis=1)
        
    
       
        # Temporal derivative and ReLU = acoustic onsets 
        rate = np.maximum(np.diff(env, prepend=env[0]), 0)
        rate = scipy.signal.resample(rate, len(env))
        
        spec = scipy.signal.resample(spec, len(env))
        env_target = min_max_scaler.fit_transform(env.reshape(-1,1))
        rate_target = min_max_scaler.fit_transform(rate.reshape(-1,1))

        

    
    
        ###Same for the distractor
        spec= naplib.features.auditory_spectrogram(distractor, sr)
    
        # Extract the envelope by taking the mean over frequencies
        env = np.mean(spec, axis=1)
    
      
    
        # Temporal derivative and ReLU = acoustic onsets 
        rate = np.maximum(np.diff(env, prepend=env[0]), 0)
        rate = scipy.signal.resample(rate, len(env))

        env = min_max_scaler.fit_transform(env.reshape(-1,1))
        rate = min_max_scaler.fit_transform(rate.reshape(-1,1))


        zer = np.array([0]*64)
        env_target = env_target.reshape(env_target.shape[0])
        rate_target = rate_target.reshape(env_target.shape[0])
        
      
        
        rates_target.append(rate_target)
        envelopes_target.append(env_target)

        
        rates_dis.append(rate)
        envelopes_dis.append(env)
    
        spec = scipy.signal.resample(spec, len(env))
    
        spec_dis.append(spec)
    
            
    
    resample_kwargs = {'num': 8, 'axis': 1}
   # specs_target = naplib.array_ops.concat_apply(spec_target, scipy.signal.resample, function_kwargs=resample_kwargs)
    #specs_dis = naplib.array_ops.concat_apply(spec_dis, scipy.signal.resample, function_kwargs=resample_kwargs)


    with open("/data/pt_03114/trf_input/{sub}/envelope_target_{sub}_125.pickle".format(sub = sub), "wb") as output_file:
        pickle.dump(envelopes_target, output_file)
    
    with open("/data/pt_03114/trf_input/{sub}/envelope_dis_{sub}_125.pickle".format(sub = sub), "wb") as output_file:
        pickle.dump(envelopes_dis, output_file)
    
    
    with open("/data/pt_03114/trf_input/{sub}/rate_target_{sub}_125.pickle".format(sub = sub), "wb") as output_file:
        pickle.dump(rates_target, output_file)
    
    with open("/data/pt_03114/trf_input/{sub}/rate_dis_{sub}_125.pickle".format(sub = sub), "wb") as output_file:
        pickle.dump(rates_dis, output_file)

# %% [markdown]
# ## F0

# %%
from scipy.signal import butter, filtfilt, find_peaks
import librosa 
import naplib
from scipy.signal import resample, lfilter
import logging
import scipy
import pickle
import os
import pandas as pd 
from scipy.stats import zscore
import numpy as np
import matplotlib.pyplot as plt
logging.getLogger("naplib").setLevel(logging.FATAL)

subs = ['sub05']

target_f0 = []
dis_f0 = []

target_f0_means = []
dis_f0_means = []

for sub in subs:
    subnum = sub[3:]
    subnum = int(subnum)
    if subnum > 15 and subnum != 41:
        path_sub = "/data/pt_02917/data/{s}/main_exp/{s}_mainexp.csv".format(s = sub)
    elif subnum == 41:
        path_sub = "/data/pt_02917/data/sub41/main_exp/41_mainexp.csv"
    else:
        path_sub = "/data/pt_02917/data/{s}/main_exp/{s}_mainexp.csv".format(s = sub)

    df = pd.read_csv(path_sub, sep = ";")

    if subnum == 41:
        df['subject'] = "sub41"
        
    
    target_path = "/data/pt_02917/behavior_stimuli/targets_final_norm/"
    distractor_path = "/data/pt_02917/behavior_stimuli/distractors_new_clean/"
    
    specs = []
    envelopes = []
    rates = []
    #subdat = subdat.sort_values(by = "target")
    
    cutoff=20.
    comp_factor=1./3
    resample=128
    band=[1,10]
    
    for i,r in df.iterrows():
        target, sr = librosa.load(target_path + r['target'], sr = 44100)
        distractor, sr = librosa.load(distractor_path + r['distractor'], sr = 44100)
    
       # zero pad the target
        zer = np.array([0]*22050)
        y1_sil = np.concatenate((zer,target))
        
        zer2 = np.array([0]*(len(distractor)-len(y1_sil)))
        target_pad = np.concatenate((y1_sil, zer2))
    
  

        f0t,v,vp= librosa.pyin(target_pad,sr=sr,fmin=75, fmax=175)
        f0d,v,vp = librosa.pyin(distractor,sr=sr,fmin=120, fmax=300)

      
        
        f0t_p = np.nan_to_num(f0t, nan = np.nanmean(f0t))
        f0d_p = np.nan_to_num(f0d, nan = np.nanmean(f0d))

        
         ###Calculate the spectrogram 
        spec= naplib.features.auditory_spectrogram(target_pad, sr)
    
        # Extract the envelope by taking the mean over frequencies
        env = np.mean(spec, axis=1)
     #   print(len(env))
      #  print(len(f0t_p))
        f0t_p = scipy.signal.resample(f0t_p, len(env))
        f0d_p = scipy.signal.resample(f0d_p, len(env))

        target_f0.append(f0t_p)
        dis_f0.append(f0d_p)

        
     

   

all_f0_t = np.concatenate(target_f0)
all_f0_d = np.concatenate(dis_f0)

all_f0 = np.concatenate([all_f0_t, all_f0_d])

mean_f0 = np.mean(all_f0)
std_f0 = np.std(all_f0)

f0_target_stan = []
f0_dis_stan = []
for i,f in enumerate(target_f0):
    target_f0_stan = (f-mean_f0)/std_f0
    dis_f0_stan = (dis_f0[i]-mean_f0)/std_f0
    f0_target_stan.append(target_f0_stan)
    f0_dis_stan.append(dis_f0_stan)
        


with open("/data/pt_03114/trf_input/f0_target_125.pickle", "wb") as output_file:
    pickle.dump(f0_target_stan, output_file)

with open("/data/pt_03114/trf_input/f0_dis_125.pickle", "wb") as output_file:
    pickle.dump(f0_dis_stan, output_file)

# %%
with open("/data/pt_03114/trf_input/f0_target_new.pickle", "rb") as output_file:
    o=pickle.load(output_file)

# %%
plt.plot(f0_target_stan[0])
plt.plot(o[0])

# %% [markdown]
# ## Speaker features

# %%
rat = pd.read_csv("/data/tu_barchet_cloud/owncloud-gwdg/data_analysis/ratings/ratings.csv")

vertrauen = rat.iloc[1]['vertrauen.response']
age = rat.iloc[1]['age.response']
gebildet = rat.iloc[1]['gebildet.response']

dominant = rat.iloc[1]['Dominant.response']
attraktiv = rat.iloc[1]['Attraktiv.response']
gesund=rat.iloc[1]['gesund.response']
professionell = rat.iloc[1]['professionell.response']

# %%
stim_number = []
vertrauen_upsampled = []
age_upsampled = []
gebildet_upsampled = []
dominant_upsampled = []
attraktiv_upsampled = []
word_onset_upsampled = []
gesund_upsampled = []
professionell_upsampled=[]

sentnum = 0
for s_i in df_full['target_id'].unique():
    matches = []
    aud_trial = []
    up = []
    
    s_df = df_full[df_full['target_id'] == s_i]
    stim_number.append(s_i)

    ###Upsampling to 128 Hz
    times = np.arange(0,max(s_df['end_s_x']), 1/125)
    
    ##word features
   
    word_onset_up = []

    vertrauen_up = []
    age_up = []
    gebildet_up = []
    dominant_up = []
    attraktiv_up = []
    gesund_up = []
    professionell_up=[]
 
    matches_words = []
    
    for t in s_df['start_s_x'].unique():
        ta = t 
        t_match = min(times, key=lambda x: abs(x - ta))
        matches_words.append(t_match)
        w_df = s_df[s_df['start_s_x'] == t]

 
    nummatch = 0
    for t in times:
        if t in matches_words:
            t_m = matches_words.index(t)

            vertrauen_up.append(vertrauen)
            age_up.append(age)
            gebildet_up.append(gebildet)
            dominant_up.append(dominant)
            attraktiv_up.append(attraktiv)
            gesund_up.append(gesund)
            professionell_up.append(professionell)
            
            word_onset_up.append(1)
            nummatch = nummatch +1
        else:
            vertrauen_up.append(0)
            age_up.append(0)
            gebildet_up.append(0)
            dominant_up.append(0)
            attraktiv_up.append(0)
            gesund_up.append(0)
            professionell_up.append(0)
            
            word_onset_up.append(0)

    vertrauen_upsampled.append(vertrauen_up)
    age_upsampled.append(age_up)
    gebildet_upsampled.append(gebildet_up)
    dominant_upsampled.append(dominant_up)
    attraktiv_upsampled.append(attraktiv_up)
    gesund_upsampled.append(gesund_up)
    professionell_upsampled.append(professionell_up)
    
    word_onset_upsampled.append(word_onset_up)




    sentnum = sentnum + 1

# %%
import pickle

with open("/data/pt_03114/trf_input/vertrauen_125.pickle", "wb") as output_file:
    pickle.dump(vertrauen_upsampled, output_file)

with open("/data/pt_03114/trf_input/gebildet_125.pickle", "wb") as output_file:
    pickle.dump(gebildet_upsampled, output_file)

with open("/data/pt_03114/trf_input/dominant_125.pickle", "wb") as output_file:
    pickle.dump(dominant_upsampled, output_file)


with open("/data/pt_03114/trf_input/age_125.pickle", "wb") as output_file:
    pickle.dump(age_upsampled, output_file)


with open("/data/pt_03114/trf_input/attraktiv_125.pickle", "wb") as output_file:
    pickle.dump(attraktiv_upsampled, output_file)


with open("/data/pt_03114/trf_input/gesund_125.pickle", "wb") as output_file:
    pickle.dump(gesund_upsampled, output_file)


with open("/data/pt_03114/trf_input/professionell_125.pickle", "wb") as output_file:
    pickle.dump(professionell_upsampled, output_file)

# %%
vertrauen = rat.iloc[0]['vertrauen.response']
age = rat.iloc[0]['age.response']
gebildet = rat.iloc[0]['gebildet.response']

dominant = rat.iloc[0]['Dominant.response']
attraktiv = rat.iloc[0]['Attraktiv.response']
gesund = rat.iloc[0]['gesund.response']
professionell = rat.iloc[0]['professionell.response']

# %%
stim_number = []
vertrauen_upsampled = []
age_upsampled = []
gebildet_upsampled = []
dominant_upsampled = []
attraktiv_upsampled = []
word_onset_upsampled = []
gesund_upsampled = []
professionell_upsampled=[]

sentnum = 0
for s_i in merge_surpdis_freq['id'].unique():
    matches = []
    aud_trial = []
    up = []
    
    s_df = merge_surpdis_freq[merge_surpdis_freq['id'] == s_i]
    stim_number.append(s_i)

    ###Upsampling to 128 Hz
    times = np.arange(0,max(s_df['end_s_x']), 1/125)
    
    ##word features
   
    word_onset_up = []

    vertrauen_up = []
    age_up = []
    gebildet_up = []
    dominant_up = []
    attraktiv_up = []
    gesund_up = []
    professionell_up=[]
 
    matches_words = []
    
    for t in s_df['start_s_x'].unique():
        ta = t 
        t_match = min(times, key=lambda x: abs(x - ta))
        matches_words.append(t_match)
        w_df = s_df[s_df['start_s_x'] == t]

 
    nummatch = 0
    for t in times:
        if t in matches_words:
            t_m = matches_words.index(t)

            vertrauen_up.append(vertrauen)
            age_up.append(age)
            gebildet_up.append(gebildet)
            dominant_up.append(dominant)
            attraktiv_up.append(attraktiv)
            gesund_up.append(gesund)
            professionell_up.append(professionell)
            
            word_onset_up.append(1)
            nummatch = nummatch +1
        else:
            vertrauen_up.append(0)
            age_up.append(0)
            gebildet_up.append(0)
            dominant_up.append(0)
            attraktiv_up.append(0)
            gesund_up.append(0)
            professionell_up.append(0)
            
            word_onset_up.append(0)

    vertrauen_upsampled.append(vertrauen_up)
    age_upsampled.append(age_up)
    gebildet_upsampled.append(gebildet_up)
    dominant_upsampled.append(dominant_up)
    attraktiv_upsampled.append(attraktiv_up)
    gesund_upsampled.append(gesund_up)
    professionell_upsampled.append(professionell_up)
    
    word_onset_upsampled.append(word_onset_up)

# %%
import pickle

with open("/data/pt_03114/trf_input/vertrauen_dis_125.pickle", "wb") as output_file:
    pickle.dump(vertrauen_upsampled, output_file)

with open("/data/pt_03114/trf_input/gebildet_dis_125.pickle", "wb") as output_file:
    pickle.dump(gebildet_upsampled, output_file)

with open("/data/pt_03114/trf_input/dominant_dis_125.pickle", "wb") as output_file:
    pickle.dump(dominant_upsampled, output_file)


with open("/data/pt_03114/trf_input/age_dis_125.pickle", "wb") as output_file:
    pickle.dump(age_upsampled, output_file)


with open("/data/pt_03114/trf_input/attraktiv_dis_125.pickle", "wb") as output_file:
    pickle.dump(attraktiv_upsampled, output_file)

with open("/data/pt_03114/trf_input/gesund_dis_125.pickle", "wb") as output_file:
    pickle.dump(gesund_upsampled, output_file)


with open("/data/pt_03114/trf_input/professionell_dis_125.pickle", "wb") as output_file:
    pickle.dump(professionell_upsampled, output_file)
