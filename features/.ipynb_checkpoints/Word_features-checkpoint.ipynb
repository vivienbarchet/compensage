# %% [markdown]
# # Extracting word surprisal from GPT-2

# %%
import math
import csv
import torch
from transformers import GPT2LMHeadModel, GPT2TokenizerFast
import numpy as np
import pandas as pd
import pickle
from collections import defaultdict
import re, os
import bisect
import kenlm
from string import punctuation
import scipy
import os, torch
from transformers import AutoTokenizer, GPT2LMHeadModel
import numpy as np
import pandas as pd
# Out:
# 2025-10-14 11:17:28.918438: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-14 11:17:31.338297: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760433451.862066    3730 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760433452.017334    3730 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760433453.285734    3730 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760433453.285784    3730 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760433453.285788    3730 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760433453.285792    3730 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-14 11:17:33.367609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Calculating GPT 2 surprisal and entropy

# %%
import pandas as pd

def extract_surprisal(stim):
    #load the sentences (target or distractor)
    sentence_list = pd.read_csv('target_distractor_final_final.csv', sep = ";")
    if stim == "target": 
        sentences = sentence_list['target_sent']
        sentence_id = sentence_list['id']
    else: 
        sentences = sentence_list['distractor_sent']
        sentence_id = sentence_list['id_dis']

        
    
    model = GPT2LMHeadModel.from_pretrained("dbmdz/german-gpt2")
    model.eval()
    tokenizer = AutoTokenizer.from_pretrained("dbmdz/german-gpt2")
    
    softmax = torch.nn.Softmax(dim=-1)
    ctx_size = model.config.max_position_embeddings
    bos_id = model.config.bos_token_id
    sentnum = 0
    
    words_sent = []
    word_suprisal = []
    word_entropy = []
    sentence_ids = []
    word_order = []
    
    #sentences = sentences[40:44]
    for sent in sentences:
        batches = []
        sent = sent.replace('.', '')
        sent = sent.replace(',', '')
        
        words = sent.split(" ")
        id_sentence = sentence_id[sentnum]
    
        tokenizer_output = tokenizer(sent)
        ids = tokenizer_output.input_ids
        attn = tokenizer_output.attention_mask
        start_idx = 0
        word_o = 1
    
        while len(ids) > ctx_size:
            batches.append((torch.tensor([bos_id] + ids[:ctx_size-1]).unsqueeze(0),
                            torch.tensor([1] + attn[:ctx_size-1]).unsqueeze(0), start_idx))
            ids = ids[int(ctx_size/2):]
            attn = attn[int(ctx_size/2):]
            start_idx = int(ctx_size/2) - 1
    
        batches.append((torch.tensor([bos_id] + ids).unsqueeze(0),
                        torch.tensor([1] + attn).unsqueeze(0), start_idx))
    
        curr_word_ix = 0
        curr_word_surp = []
        curr_word_ent = []
        curr_toks = ""
    
        for batch_ids, batch_attn, start_idx in batches:
            
            batch_input = {'input_ids': batch_ids, 'attention_mask': batch_attn}
            with torch.no_grad():
                model_output = model(**batch_input)
    
            logits = model_output.logits.squeeze(0)
            probs = softmax(logits)
            log_probs = torch.log2(probs)
            entropy = -torch.sum(probs * log_probs, dim=-1)  # [seq_len]
            
            target_ids = batch_ids.squeeze(0)[1:]  # shift by one
            toks = tokenizer.convert_ids_to_tokens(batch_ids.squeeze(0))[1:]
            index = torch.arange(len(target_ids))
            surprisal = -torch.log2(softmax(logits)[index, target_ids])
    
            for i in range(start_idx, len(toks)):
                cleaned_tok = toks[i].replace("Ġ", "", 1)
                cleaned_tok = cleaned_tok.replace("Ãľ", "Ü").encode("utf-8").decode("utf-8")
                cleaned_tok = cleaned_tok.replace("Ã¼", "ü").encode("utf-8").decode("utf-8")
                cleaned_tok = cleaned_tok.replace("Ã¶", "ö").encode("utf-8").decode("utf-8")
                cleaned_tok = cleaned_tok.replace("Ã¤", "ä").encode("utf-8").decode("utf-8")
                
                cleaned_tok = cleaned_tok.replace("ÃŁ", "ß").encode("utf-8").decode("utf-8")
                cleaned_tok = cleaned_tok.replace("ÃĦ", "Ä").encode("utf-8").decode("utf-8")
                cleaned_tok = cleaned_tok.replace("Ãĸ", "Ö").encode("utf-8").decode("utf-8")
                cleaned_tok = cleaned_tok.replace("Ã©", "é").encode("utf-8").decode("utf-8")
                
          
    
                curr_word_surp.append(surprisal[i].item())
                curr_word_ent.append(entropy[i].item())
                curr_toks += cleaned_tok
    
                words[curr_word_ix] = words[curr_word_ix].replace(cleaned_tok, "", 1)
                if words[curr_word_ix] == "":
                    words_sent.append(curr_toks)
                    word_suprisal.append(sum(curr_word_surp))
                    word_entropy.append(sum(curr_word_ent))
                    sentence_ids.append(id_sentence)
                    word_order.append(word_o)
    
                    word_o += 1
                    curr_word_surp = []
                    curr_word_ent = []
                    curr_toks = ""
                    curr_word_ix += 1
    
        sentnum += 1


    surprisal_df = pd.DataFrame(zip(words_sent, word_suprisal, word_entropy,sentence_ids, word_order), columns = ['words', 'surprisal','entropy', 'id', 'word_order'])
    surprisal_df['surprisal_new']= np.where(surprisal_df['word_order'] == 1, np.nan, surprisal_df['surprisal'])

    surprisal_df_filt.to_csv("./trf_input/word_surprisal_gpt_{s}.csv".format(s=stim), encoding = "utf-8")

#Word frequency
def extract_word_frequency(stim): 

    subtlex = pd.read_excel("./SUBTLEX-DE cleaned with Google00 frequencies.xlsx")
    target_list = pd.read_csv('./target_distractor_final_final.csv', sep = ";")
    
    subtlex = subtlex.dropna(subset = "Word")
    subtlex = subtlex[['Word', 'lgSUBTLEX']]
    subtlex['Word'] = subtlex['Word'].str.lower()
    
    
   
    
    words_sent = []
    word_freq = []
    sentence_ids = []
    word_order = []
    
    
    
    for i,r in target_list.iterrows():
        
        if stim == "target": 
            sent = r['target_sent']
            ids = r['id']
        else: 
            sent = r['distractor_sent']
            ids = r['id_dis']
            
    

        
        wordlist = sent.split(" ")
        wo = 1
        for w in wordlist:
            w = w.replace(",", "")
            w = w.replace(',', '')
            w = w.replace(':', '')
            w = w.replace('!', '')
            w = w.replace('"', '')
            w = w.replace('.', '')
    
            w = w.lower()
            f_p = subtlex[subtlex['Word'] == w]
    
            if len(f_p) == 0:
                w = w.replace("ß", "ss")
                f_p = subtlex[subtlex['Word'] == w]
    
            if len(f_p) == 1:
                word_freq.append(f_p['lgSUBTLEX'].iloc[0])
            
            elif len(f_p) == 0:
                word_freq.append(np.min(subtlex['lgSUBTLEX']))
            else:
                print(w)
    
            words_sent.append(w)
            sentence_ids.append(ids)
            word_order.append(wo)
            wo = wo + 1
                
    
    word_freq_df = pd.DataFrame(zip(sentence_ids, word_order, words_sent, word_freq), columns = ['id', 'word_order', 'word', 'frequency'])
    word_freq_df.to_csv('./trf_input/word_frequency_{s}_lgsubtlex.csv'.format(s=stim))

# %%
for stim in ['target', 'dis']:
    extract_surprisal(stim)
    extract_word_frequency(stim)
# Out:
# Token: Fr
#   Surprisal: 20.56
# Token: ische
#   Surprisal: 5.70
# Token: Gard
#   Surprisal: 18.69
# Token: inen
#   Surprisal: 0.18
# Token: hängen
#   Surprisal: 10.52
# Token: am
#   Surprisal: 5.32
# Token: Fenster
#   Surprisal: 2.82
# Token: riegel
#   Surprisal: 13.19
# Token: Der
#   Surprisal: 18.26
# Token: Regen
#   Surprisal: 11.33
# Token: trop
#   Surprisal: 11.25
# Token: ft
#   Surprisal: 0.07
# Token: vom
#   Surprisal: 4.90
# Token: Dach
#   Surprisal: 7.16
# Token: riegel
#   Surprisal: 19.90
# Token: Montag
#   Surprisal: 27.37
# Token: war
#   Surprisal: 10.88
# Token: es
#   Surprisal: 5.32
# Token: uns
#   Surprisal: 7.73
# Token: zu
#   Surprisal: 6.25
# Token: reg
#   Surprisal: 17.92
# Token: ner
#   Surprisal: 3.59
# Token: isch
#   Surprisal: 0.13
# Token: riegel
#   Surprisal: 35.02
# Token: Der
#   Surprisal: 18.26
# Token: Bus
#   Surprisal: 10.55
# Token: hu
#   Surprisal: 12.36
# Token: pt
#   Surprisal: 2.47
# Token: vor
#   Surprisal: 5.85
# Token: der
#   Surprisal: 3.41
# Token: bel
#   Surprisal: 14.95
# Token: eb
#   Surprisal: 0.47
# Token: ten
#   Surprisal: 0.13
# Token: Haltestelle
#   Surprisal: 5.29
# Token: riegel
#   Surprisal: 28.64
# Token: Sie
#   Surprisal: 18.28
# Token: trägt
#   Surprisal: 12.36
# Token: ein
#   Surprisal: 4.91
# Token: Lächeln
#   Surprisal: 8.12
# Token: im
#   Surprisal: 3.66
# Token: Gesicht
#   Surprisal: 0.24
# Token: riegel
#   Surprisal: 27.15
# Token: Kinder
#   Surprisal: 21.90
# Token: spielen
#   Surprisal: 9.92
# Token: fröhlich
#   Surprisal: 12.52
# Token: im
#   Surprisal: 5.07
# Token: Park
#   Surprisal: 5.78
# Token: riegel
#   Surprisal: 19.20
# Token: Ein
#   Surprisal: 18.19
# Token: Schiff
#   Surprisal: 8.87
# Token: g
#   Surprisal: 12.22
# Token: leitet
#   Surprisal: 2.85
# Token: über
#   Surprisal: 3.56
# Token: das
#   Surprisal: 3.60
# Token: Wasser
#   Surprisal: 1.99
# Token: riegel
#   Surprisal: 23.43
# Token: Sie
#   Surprisal: 18.28
# Token: läuft
#   Surprisal: 15.63
# Token: entspannt
#   Surprisal: 13.95
# Token: am
#   Surprisal: 7.33
# Token: Strand
#   Surprisal: 4.72
# Token: entlang
#   Surprisal: 0.51
# Token: riegel
#   Surprisal: 27.12
# Token: Die
#   Surprisal: 17.84
# Token: Rinder
#   Surprisal: 13.47
# Token: sind
#   Surprisal: 4.10
# Token: noch
#   Surprisal: 6.01
# Token: auf
#   Surprisal: 5.50
# Token: der
#   Surprisal: 1.88
# Token: Weide
#   Surprisal: 0.65
# Token: riegel
#   Surprisal: 23.19
# Token: Die
#   Surprisal: 17.84
# Token: Vögel
#   Surprisal: 13.08
# Token: umk
#   Surprisal: 14.24
# Token: rei
#   Surprisal: 0.20
# Token: sten
#   Surprisal: 0.01
# Token: den
#   Surprisal: 3.47
# Token: Turm
#   Surprisal: 8.28
# Token: riegel
#   Surprisal: 15.40
# Token: Die
#   Surprisal: 17.84
# Token: Ärzte
#   Surprisal: 11.61
# Token: sind
#   Surprisal: 4.37
# Token: damit
#   Surprisal: 8.13
# Token: gar
#   Surprisal: 10.63
# Token: nicht
#   Surprisal: 0.04
# Token: einverstanden
#   Surprisal: 1.64
# Token: riegel
#   Surprisal: 34.64
# Token: Auf
#   Surprisal: 20.57
# Token: dem
#   Surprisal: 3.50
# Token: Brett
#   Surprisal: 11.57
# Token: leuchten
#   Surprisal: 14.62
# Token: bunte
#   Surprisal: 7.65
# Token: Tul
#   Surprisal: 10.29
# Token: pen
#   Surprisal: 0.14
# Token: riegel
#   Surprisal: 19.73
# Token: O
#   Surprisal: 17.03
# Token: pa
#   Surprisal: 8.39
# Token: j
#   Surprisal: 13.07
# Token: ammert
#   Surprisal: 14.70
# Token: ständig
#   Surprisal: 9.52
# Token: über
#   Surprisal: 2.99
# Token: seine
#   Surprisal: 3.71
# Token: Ast
#   Surprisal: 12.93
# Token: hma
#   Surprisal: 0.20
# Token: an
#   Surprisal: 2.79
# Token: fälle
#   Surprisal: 0.04
# Token: riegel
#   Surprisal: 29.17
# Token: Das
#   Surprisal: 18.88
# Token: Telefon
#   Surprisal: 11.56
# Token: klingelt
#   Surprisal: 1.88
# Token: in
#   Surprisal: 6.43
# Token: der
#   Surprisal: 1.54
# Token: stillen
#   Surprisal: 13.45
# Token: Wohnung
#   Surprisal: 7.64
# Token: riegel
#   Surprisal: 26.46
# Token: Du
#   Surprisal: 20.05
# Token: hil
#   Surprisal: 15.07
# Token: fst
#   Surprisal: 7.44
# Token: mir
#   Surprisal: 3.41
# Token: beim
#   Surprisal: 6.35
# Token: Fern
#   Surprisal: 14.08
# Token: studium
#   Surprisal: 2.38
# Token: riegel
#   Surprisal: 26.85
# Token: Dra
#   Surprisal: 24.81
# Token: ußen
#   Surprisal: 4.64
# Token: fliegt
#   Surprisal: 13.56
# Token: die
#   Surprisal: 3.76
# Token: Landschaft
#   Surprisal: 10.13
# Token: vorbei
#   Surprisal: 6.18
# Token: riegel
#   Surprisal: 26.47
# Token: Die
#   Surprisal: 17.84
# Token: Blumen
#   Surprisal: 13.24
# Token: bl
#   Surprisal: 7.46
# Token: ühen
#   Surprisal: 0.16
# Token: im
#   Surprisal: 4.21
# Token: Garten
#   Surprisal: 4.74
# Token: riegel
#   Surprisal: 22.47
# Token: Die
#   Surprisal: 17.84
# Token: Radfahrer
#   Surprisal: 14.20
# Token: erkunden
#   Surprisal: 12.28
# Token: den
#   Surprisal: 3.10
# Token: Wald
#   Surprisal: 5.25
# Token: riegel
#   Surprisal: 14.57
# Token: Un
#   Surprisal: 21.14
# Token: ruh
#   Surprisal: 12.80
# Token: ig
#   Surprisal: 5.45
# Token: tanzen
#   Surprisal: 15.63
# Token: Blätter
#   Surprisal: 16.22
# Token: im
#   Surprisal: 5.37
# Token: Sonnenschein
#   Surprisal: 7.24
# Token: riegel
#   Surprisal: 24.72
# Token: Durch
#   Surprisal: 20.92
# Token: den
#   Surprisal: 4.16
# Token: ständigen
#   Surprisal: 9.30
# Token: F
#   Surprisal: 11.46
# Token: öhn
#   Surprisal: 7.05
# Token: verd
#   Surprisal: 12.70
# Token: or
#   Surprisal: 6.03
# Token: ren
#   Surprisal: 1.98
# Token: die
#   Surprisal: 1.17
# Token: Ä
#   Surprisal: 7.61
# Token: hren
#   Surprisal: 4.43
# Token: riegel
#   Surprisal: 18.98
# Token: Bei
#   Surprisal: 21.51
# Token: dem
#   Surprisal: 5.11
# Token: Peit
#   Surprisal: 18.77
# Token: schen
#   Surprisal: 1.16
# Token: kn
#   Surprisal: 5.83
# Token: all
#   Surprisal: 0.16
# Token: sch
#   Surprisal: 8.10
# Token: euten
#   Surprisal: 11.59
# Token: die
#   Surprisal: 1.50
# Token: R
#   Surprisal: 8.77
# Token: össer
#   Surprisal: 4.43
# Token: riegel
#   Surprisal: 23.28
# Token: Ein
#   Surprisal: 18.19
# Token: st
#   Surprisal: 7.92
# Token: weilen
#   Surprisal: 3.06
# Token: ist
#   Surprisal: 3.21
# Token: Erfolg
#   Surprisal: 17.42
# Token: die
#   Surprisal: 7.45
# Token: Hauptsache
#   Surprisal: 6.56
# Token: riegel
#   Surprisal: 29.13
# Token: Durch
#   Surprisal: 20.92
# Token: Wald
#   Surprisal: 15.57
# Token: und
#   Surprisal: 2.43
# Token: Feld
#   Surprisal: 3.35
# Token: führt
#   Surprisal: 3.86
# Token: unser
#   Surprisal: 7.84
# Token: Weg
#   Surprisal: 0.50
# Token: riegel
#   Surprisal: 18.01
# Token: Der
#   Surprisal: 18.26
# Token: Regen
#   Surprisal: 11.33
# Token: kl
#   Surprisal: 11.05
# Token: opft
#   Surprisal: 3.61
# Token: ans
#   Surprisal: 11.16
# Token: Fenster
#   Surprisal: 2.41
# Token: riegel
#   Surprisal: 17.44
# Token: Der
#   Surprisal: 18.26
# Token: Regen
#   Surprisal: 11.33
# Token: schirm
#   Surprisal: 4.47
# Token: schützt
#   Surprisal: 7.14
# Token: vor
#   Surprisal: 2.81
# Token: plötzlich
#   Surprisal: 15.02
# Token: em
#   Surprisal: 0.74
# Token: Regen
#   Surprisal: 1.45
# Token: riegel
#   Surprisal: 21.50
# Token: Motoren
#   Surprisal: 26.80
# Token: brauchen
#   Surprisal: 13.34
# Token: Benzin
#   Surprisal: 11.45
# Token: Öl
#   Surprisal: 15.54
# Token: und
#   Surprisal: 3.33
# Token: Wasser
#   Surprisal: 4.89
# Token: riegel
#   Surprisal: 22.44
# Token: Die
#   Surprisal: 17.84
# Token: Blumen
#   Surprisal: 13.24
# Token: bl
#   Surprisal: 7.46
# Token: ühen
#   Surprisal: 0.16
# Token: im
#   Surprisal: 4.21
# Token: Winter
#   Surprisal: 5.95
# Token: blau
#   Surprisal: 10.69
# Token: riegel
#   Surprisal: 23.22
# Token: Der
#   Surprisal: 18.26
# Token: Arzt
#   Surprisal: 11.53
# Token: untersucht
#   Surprisal: 10.26
# Token: den
#   Surprisal: 3.53
# Token: Patienten
#   Surprisal: 3.54
# Token: riegel
#   Surprisal: 25.65
# Token: Der
#   Surprisal: 18.26
# Token: Lehrer
#   Surprisal: 12.22
# Token: erklärt
#   Surprisal: 9.95
# Token: schwierige
#   Surprisal: 16.10
# Token: Konzepte
#   Surprisal: 11.75
# Token: riegel
#   Surprisal: 31.18
# Token: Der
#   Surprisal: 18.26
# Token: Nachbar
#   Surprisal: 12.16
# Token: trägt
#   Surprisal: 10.70
# Token: immer
#   Surprisal: 7.08
# Token: Hü
#   Surprisal: 11.98
# Token: te
#   Surprisal: 0.12
# Token: riegel
#   Surprisal: 19.75
# Token: Junge
#   Surprisal: 30.47
# Token: Erwachsene
#   Surprisal: 10.50
# Token: genießen
#   Surprisal: 8.73
# Token: das
#   Surprisal: 3.92
# Token: Stadt
#   Surprisal: 9.65
# Token: fest
#   Surprisal: 1.43
# Token: riegel
#   Surprisal: 26.11
# Token: Sechs
#   Surprisal: 25.08
# Token: Mädchen
#   Surprisal: 10.82
# Token: wollen
#   Surprisal: 8.12
# Token: Schwester
#   Surprisal: 15.83
# Token: werden
#   Surprisal: 5.10
# Token: riegel
#   Surprisal: 31.01
# Token: Die
#   Surprisal: 17.84
# Token: Krankenschwester
#   Surprisal: 16.47
# Token: j
#   Surprisal: 13.56
# Token: on
#   Surprisal: 3.21
# Token: gl
#   Surprisal: 0.03
# Token: iert
#   Surprisal: 0.32
# Token: mit
#   Surprisal: 2.48
# Token: Medikamenten
#   Surprisal: 10.22
# Token: riegel
#   Surprisal: 15.51
# Token: Die
#   Surprisal: 17.84
# Token: Kartoffeln
#   Surprisal: 14.10
# Token: gehören
#   Surprisal: 8.59
# Token: zum
#   Surprisal: 3.94
# Token: Mittagessen
#   Surprisal: 8.18
# Token: riegel
#   Surprisal: 22.06
# Token: Der
#   Surprisal: 18.26
# Token: Regen
#   Surprisal: 11.33
# Token: pr
#   Surprisal: 9.31
# Token: ass
#   Surprisal: 0.04
# Token: elt
#   Surprisal: 0.35
# Token: auf
#   Surprisal: 2.20
# Token: das
#   Surprisal: 3.49
# Token: Dach
#   Surprisal: 4.43
# Token: fenster
#   Surprisal: 12.32
# Token: riegel
#   Surprisal: 23.58
# Token: Morgen
#   Surprisal: 24.67
# Token: wird
#   Surprisal: 8.24
# Token: es
#   Surprisal: 2.71
# Token: ne
#   Surprisal: 12.32
# Token: blig
#   Surprisal: 2.42
# Token: und
#   Surprisal: 3.68
# Token: eisk
#   Surprisal: 11.43
# Token: alt
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 34.04
# Token: Der
#   Surprisal: 18.26
# Token: Regen
#   Surprisal: 11.33
# Token: spielt
#   Surprisal: 10.13
# Token: Klavier
#   Surprisal: 12.83
# Token: auf
#   Surprisal: 7.98
# Token: den
#   Surprisal: 3.88
# Token: D
#   Surprisal: 6.46
# Token: ächern
#   Surprisal: 0.04
# Token: riegel
#   Surprisal: 28.56
# Token: Die
#   Surprisal: 17.84
# Token: Tante
#   Surprisal: 15.77
# Token: bewohnt
#   Surprisal: 18.81
# Token: ein
#   Surprisal: 2.07
# Token: nett
#   Surprisal: 10.31
# Token: es
#   Surprisal: 0.01
# Token: Häuschen
#   Surprisal: 4.89
# Token: riegel
#   Surprisal: 28.78
# Token: Wir
#   Surprisal: 18.92
# Token: wollen
#   Surprisal: 6.44
# Token: heute
#   Surprisal: 8.63
# Token: spazieren
#   Surprisal: 14.62
# Token: gehen
#   Surprisal: 0.40
# Token: riegel
#   Surprisal: 34.76
# Token: Die
#   Surprisal: 17.84
# Token: Entscheidung
#   Surprisal: 9.16
# Token: darfst
#   Surprisal: 20.58
# Token: du
#   Surprisal: 0.19
# Token: selbst
#   Surprisal: 6.81
# Token: fällen
#   Surprisal: 5.29
# Token: riegel
#   Surprisal: 34.62
# Token: Die
#   Surprisal: 17.84
# Token: Straßen
#   Surprisal: 11.64
# Token: sind
#   Surprisal: 4.19
# Token: voller
#   Surprisal: 4.57
# Token: fröh
#   Surprisal: 12.18
# Token: licher
#   Surprisal: 0.02
# Token: Passanten
#   Surprisal: 9.41
# Token: riegel
#   Surprisal: 22.91
# Token: Sie
#   Surprisal: 18.28
# Token: hat
#   Surprisal: 7.00
# Token: die
#   Surprisal: 3.96
# Token: Neu
#   Surprisal: 11.67
# Token: igkeit
#   Surprisal: 1.85
# Token: mit
#   Surprisal: 7.24
# Token: Gen
#   Surprisal: 9.54
# Token: ugt
#   Surprisal: 1.56
# Token: u
#   Surprisal: 0.02
# Token: ung
#   Surprisal: 0.02
# Token: aufgenommen
#   Surprisal: 1.06
# Token: riegel
#   Surprisal: 33.83
# Token: Er
#   Surprisal: 20.51
# Token: hat
#   Surprisal: 6.74
# Token: eine
#   Surprisal: 4.20
# Token: sp
#   Surprisal: 11.06
# Token: rung
#   Surprisal: 3.89
# Token: hafte
#   Surprisal: 0.95
# Token: Gang
#   Surprisal: 10.38
# Token: art
#   Surprisal: 0.59
# Token: riegel
#   Surprisal: 26.68
# Token: Der
#   Surprisal: 18.26
# Token: alte
#   Surprisal: 10.05
# Token: Baum
#   Surprisal: 6.88
# Token: erzählte
#   Surprisal: 15.68
# Token: vom
#   Surprisal: 4.84
# Token: Leben
#   Surprisal: 3.41
# Token: riegel
#   Surprisal: 28.70
# Token: Sein
#   Surprisal: 20.84
# Token: Blick
#   Surprisal: 9.79
# Token: strei
#   Surprisal: 13.18
# Token: fte
#   Surprisal: 0.03
# Token: die
#   Surprisal: 2.40
# Token: Sterne
#   Surprisal: 10.79
# Token: riegel
#   Surprisal: 24.13
# Token: Bei
#   Surprisal: 21.51
# Token: Konkurs
#   Surprisal: 15.40
# Token: kennt
#   Surprisal: 16.60
# Token: der
#   Surprisal: 3.45
# Token: Richter
#   Surprisal: 7.92
# Token: keine
#   Surprisal: 3.50
# Token: Gnade
#   Surprisal: 0.93
# Token: riegel
#   Surprisal: 30.41
# Token: Die
#   Surprisal: 17.84
# Token: Musiker
#   Surprisal: 12.39
# Token: unterhalten
#   Surprisal: 10.90
# Token: Passanten
#   Surprisal: 14.55
# Token: mit
#   Surprisal: 3.16
# Token: ihrer
#   Surprisal: 4.42
# Token: Musik
#   Surprisal: 1.50
# Token: riegel
#   Surprisal: 24.24
# Token: Heute
#   Surprisal: 25.96
# Token: jeder
#   Surprisal: 16.02
# Token: Strauß
#   Surprisal: 16.44
# Token: Blumen
#   Surprisal: 6.86
# Token: zwei
#   Surprisal: 14.09
# Token: Mark
#   Surprisal: 9.95
# Token: riegel
#   Surprisal: 20.40
# Token: Das
#   Surprisal: 18.88
# Token: amtliche
#   Surprisal: 14.62
# Token: Amtsblatt
#   Surprisal: 6.65
# Token: liegt
#   Surprisal: 11.37
# Token: über
#   Surprisal: 10.25
# Token: m
#   Surprisal: 14.70
# Token: Durchschnitt
#   Surprisal: 11.99
# Token: riegel
#   Surprisal: 24.81
# Token: Diese
#   Surprisal: 21.25
# Token: Durch
#   Surprisal: 15.60
# Token: sage
#   Surprisal: 4.97
# Token: ist
#   Surprisal: 2.96
# Token: ohne
#   Surprisal: 11.16
# Token: Gewähr
#   Surprisal: 5.38
# Token: riegel
#   Surprisal: 29.15
# Token: Ein
#   Surprisal: 18.19
# Token: Musiker
#   Surprisal: 13.37
# Token: verz
#   Surprisal: 11.79
# Token: aubert
#   Surprisal: 0.91
# Token: die
#   Surprisal: 2.46
# Token: Menschen
#   Surprisal: 4.04
# Token: menge
#   Surprisal: 11.48
# Token: riegel
#   Surprisal: 32.92
# Token: Die
#   Surprisal: 17.84
# Token: Blumen
#   Surprisal: 13.24
# Token: bl
#   Surprisal: 7.46
# Token: ühen
#   Surprisal: 0.16
# Token: bunt
#   Surprisal: 10.70
# Token: im
#   Surprisal: 5.37
# Token: Blum
#   Surprisal: 9.96
# Token: enk
#   Surprisal: 1.47
# Token: asten
#   Surprisal: 3.27
# Token: riegel
#   Surprisal: 22.17
# Token: In
#   Surprisal: 16.59
# Token: der
#   Surprisal: 5.12
# Token: D
#   Surprisal: 8.83
# Token: ämmerung
#   Surprisal: 3.11
# Token: kommen
#   Surprisal: 9.69
# Token: wir
#   Surprisal: 4.03
# Token: heim
#   Surprisal: 11.47
# Token: riegel
#   Surprisal: 24.33
# Token: Er
#   Surprisal: 20.51
# Token: wird
#   Surprisal: 7.51
# Token: ihr
#   Surprisal: 10.25
# Token: ewig
#   Surprisal: 12.39
# Token: treu
#   Surprisal: 2.74
# Token: bleiben
#   Surprisal: 2.12
# Token: riegel
#   Surprisal: 31.82
# Token: Über
#   Surprisal: 20.36
# Token: die
#   Surprisal: 5.88
# Token: Felder
#   Surprisal: 12.80
# Token: weht
#   Surprisal: 10.66
# Token: ein
#   Surprisal: 3.14
# Token: Wind
#   Surprisal: 3.58
# Token: riegel
#   Surprisal: 19.14
# Token: Hier
#   Surprisal: 22.76
# Token: richten
#   Surprisal: 15.40
# Token: Zimmer
#   Surprisal: 18.54
# Token: leute
#   Surprisal: 5.60
# Token: ein
#   Surprisal: 5.79
# Token: Dach
#   Surprisal: 7.69
# Token: riegel
#   Surprisal: 19.97
# Token: Ein
#   Surprisal: 18.19
# Token: Stück
#   Surprisal: 8.89
# Token: chen
#   Surprisal: 5.22
# Token: weiter
#   Surprisal: 4.72
# Token: nördlich
#   Surprisal: 7.82
# Token: ist
#   Surprisal: 4.39
# Token: eine
#   Surprisal: 4.28
# Token: Um
#   Surprisal: 10.13
# Token: gehungs
#   Surprisal: 2.77
# Token: straße
#   Surprisal: 0.03
# Token: riegel
#   Surprisal: 27.57
# Token: In
#   Surprisal: 16.59
# Token: ihrem
#   Surprisal: 14.79
# Token: Blick
#   Surprisal: 8.90
# Token: lag
#   Surprisal: 9.23
# Token: eine
#   Surprisal: 3.36
# Token: tiefe
#   Surprisal: 8.52
# Token: Sehnsucht
#   Surprisal: 6.80
# Token: riegel
#   Surprisal: 28.83
# Token: Wir
#   Surprisal: 18.92
# Token: haben
#   Surprisal: 3.11
# Token: ein
#   Surprisal: 5.26
# Token: Abteil
#   Surprisal: 15.02
# Token: extra
#   Surprisal: 9.62
# Token: für
#   Surprisal: 1.44
# Token: uns
#   Surprisal: 5.71
# Token: riegel
#   Surprisal: 26.28
# Token: Schn
#   Surprisal: 22.37
# Token: aps
#   Surprisal: 2.91
# Token: im
#   Surprisal: 6.47
# Token: Tee
#   Surprisal: 9.46
# Token: verf
#   Surprisal: 13.75
# Token: äl
#   Surprisal: 3.89
# Token: scht
#   Surprisal: 0.97
# Token: das
#   Surprisal: 6.25
# Token: Aroma
#   Surprisal: 3.65
# Token: riegel
#   Surprisal: 27.74
# Token: Das
#   Surprisal: 18.88
# Token: kalte
#   Surprisal: 13.47
# Token: Licht
#   Surprisal: 7.30
# Token: leuchtet
#   Surprisal: 9.83
# Token: am
#   Surprisal: 6.34
# Token: Morgen
#   Surprisal: 4.12
# Token: riegel
#   Surprisal: 23.75
# Token: Ihr
#   Surprisal: 20.83
# Token: Lachen
#   Surprisal: 16.00
# Token: h
#   Surprisal: 9.83
# Token: all
#   Surprisal: 5.23
# Token: te
#   Surprisal: 3.40
# Token: durch
#   Surprisal: 2.45
# Token: den
#   Surprisal: 2.14
# Token: leeren
#   Surprisal: 8.85
# Token: Park
#   Surprisal: 10.56
# Token: riegel
#   Surprisal: 16.76
# Token: Nach
#   Surprisal: 19.36
# Token: der
#   Surprisal: 2.75
# Token: harten
#   Surprisal: 10.90
# Token: Arbeit
#   Surprisal: 4.30
# Token: brauche
#   Surprisal: 13.27
# Token: ich
#   Surprisal: 0.19
# Token: Zerst
#   Surprisal: 21.59
# Token: reuung
#   Surprisal: 1.82
# Token: riegel
#   Surprisal: 28.78
# Token: In
#   Surprisal: 16.59
# Token: den
#   Surprisal: 7.41
# Token: Bergen
#   Surprisal: 8.15
# Token: kann
#   Surprisal: 8.60
# Token: man
#   Surprisal: 1.78
# Token: Ski
#   Surprisal: 10.74
# Token: laufen
#   Surprisal: 4.36
# Token: riegel
#   Surprisal: 30.74
# Token: Am
#   Surprisal: 19.10
# Token: Himmel
#   Surprisal: 9.77
# Token: fliegt
#   Surprisal: 7.75
# Token: ein
#   Surprisal: 3.04
# Token: Schwar
#   Surprisal: 8.88
# Token: m
#   Surprisal: 0.00
# Token: Zug
#   Surprisal: 11.61
# Token: vögel
#   Surprisal: 0.04
# Token: vorbei
#   Surprisal: 4.43
# Token: riegel
#   Surprisal: 26.60
# Token: Der
#   Surprisal: 18.26
# Token: Termin
#   Surprisal: 12.23
# Token: des
#   Surprisal: 5.17
# Token: Treffpunkt
#   Surprisal: 13.33
# Token: s
#   Surprisal: 0.56
# Token: wird
#   Surprisal: 5.56
# Token: noch
#   Surprisal: 5.27
# Token: abges
#   Surprisal: 11.40
# Token: prochen
#   Surprisal: 0.28
# Token: riegel
#   Surprisal: 38.61
# Token: Die
#   Surprisal: 17.84
# Token: Sonne
#   Surprisal: 10.43
# Token: strahlt
#   Surprisal: 7.15
# Token: am
#   Surprisal: 3.85
# Token: w
#   Surprisal: 10.72
# Token: ol
#   Surprisal: 3.52
# Token: ken
#   Surprisal: 0.34
# Token: losen
#   Surprisal: 2.90
# Token: Himmel
#   Surprisal: 0.47
# Token: riegel
#   Surprisal: 30.38
# Token: Die
#   Surprisal: 17.84
# Token: Uhr
#   Surprisal: 11.59
# Token: ti
#   Surprisal: 6.33
# Token: ckt
#   Surprisal: 0.08
# Token: ruhig
#   Surprisal: 11.19
# Token: an
#   Surprisal: 7.87
# Token: der
#   Surprisal: 1.41
# Token: Wand
#   Surprisal: 3.82
# Token: riegel
#   Surprisal: 24.88
# Token: Zwölf
#   Surprisal: 28.46
# Token: Wanderer
#   Surprisal: 14.48
# Token: wollen
#   Surprisal: 7.65
# Token: den
#   Surprisal: 4.13
# Token: Gipfel
#   Surprisal: 6.51
# Token: erkl
#   Surprisal: 3.28
# Token: immen
#   Surprisal: 0.08
# Token: riegel
#   Surprisal: 31.84
# Token: L
#   Surprisal: 15.52
# Token: öst
#   Surprisal: 14.11
# Token: doch
#   Surprisal: 11.50
# Token: die
#   Surprisal: 3.85
# Token: Fahr
#   Surprisal: 11.76
# Token: karten
#   Surprisal: 4.15
# Token: am
#   Surprisal: 7.57
# Token: Schalter
#   Surprisal: 3.22
# Token: riegel
#   Surprisal: 26.15
# Token: Im
#   Surprisal: 18.80
# Token: Wald
#   Surprisal: 9.58
# Token: pl
#   Surprisal: 14.31
# Token: ät
#   Surprisal: 2.32
# Token: sch
#   Surprisal: 0.28
# Token: ert
#   Surprisal: 0.78
# Token: eine
#   Surprisal: 4.50
# Token: dunkle
#   Surprisal: 8.00
# Token: Quelle
#   Surprisal: 8.12
# Token: riegel
#   Surprisal: 27.58
# Token: Die
#   Surprisal: 17.84
# Token: Musik
#   Surprisal: 10.16
# Token: erkl
#   Surprisal: 11.08
# Token: ingt
#   Surprisal: 0.05
# Token: sanft
#   Surprisal: 8.33
# Token: im
#   Surprisal: 4.47
# Token: Raum
#   Surprisal: 3.91
# Token: riegel
#   Surprisal: 20.56
# Token: Der
#   Surprisal: 18.26
# Token: Nachbar
#   Surprisal: 12.16
# Token: sang
#   Surprisal: 13.85
# Token: unter
#   Surprisal: 9.64
# Token: der
#   Surprisal: 1.90
# Token: Dusche
#   Surprisal: 5.94
# Token: Oper
#   Surprisal: 14.95
# Token: riegel
#   Surprisal: 29.61
# Token: Ein
#   Surprisal: 18.19
# Token: b
#   Surprisal: 9.54
# Token: unter
#   Surprisal: 10.67
# Token: Schmetterling
#   Surprisal: 8.89
# Token: tanzt
#   Surprisal: 10.14
# Token: im
#   Surprisal: 4.38
# Token: Sonnen
#   Surprisal: 9.32
# Token: licht
#   Surprisal: 0.31
# Token: riegel
#   Surprisal: 26.64
# Token: Durch
#   Surprisal: 20.92
# Token: den
#   Surprisal: 4.16
# Token: Regen
#   Surprisal: 9.42
# Token: leuchtet
#   Surprisal: 16.08
# Token: das
#   Surprisal: 2.87
# Token: Feuer
#   Surprisal: 7.76
# Token: riegel
#   Surprisal: 21.66
# Token: Unser
#   Surprisal: 23.49
# Token: Doktor
#   Surprisal: 17.54
# Token: besucht
#   Surprisal: 13.41
# Token: Vater
#   Surprisal: 11.54
# Token: täglich
#   Surprisal: 10.92
# Token: riegel
#   Surprisal: 28.68
# Token: Unser
#   Surprisal: 23.49
# Token: er
#   Surprisal: 5.55
# Token: Tante
#   Surprisal: 13.98
# Token: fehlt
#   Surprisal: 12.41
# Token: gar
#   Surprisal: 7.06
# Token: nichts
#   Surprisal: 0.58
# Token: riegel
#   Surprisal: 26.14
# Token: B
#   Surprisal: 13.07
# Token: öse
#   Surprisal: 12.70
# Token: Menschen
#   Surprisal: 9.29
# Token: verdienen
#   Surprisal: 11.29
# Token: ihre
#   Surprisal: 6.91
# Token: Strafe
#   Surprisal: 5.10
# Token: riegel
#   Surprisal: 31.03
# Token: Ein
#   Surprisal: 18.19
# Token: leiser
#   Surprisal: 15.27
# Token: Wind
#   Surprisal: 6.34
# Token: ha
#   Surprisal: 8.66
# Token: uch
#   Surprisal: 0.01
# Token: st
#   Surprisal: 8.87
# Token: reift
#   Surprisal: 1.14
# Token: die
#   Surprisal: 3.28
# Token: Wiesen
#   Surprisal: 9.26
# Token: riegel
#   Surprisal: 21.32
# Token: Der
#   Surprisal: 18.26
# Token: alte
#   Surprisal: 10.05
# Token: Baum
#   Surprisal: 6.88
# Token: kn
#   Surprisal: 10.38
# Token: arrt
#   Surprisal: 4.05
# Token: bei
#   Surprisal: 6.46
# Token: jedem
#   Surprisal: 5.44
# Token: Wind
#   Surprisal: 3.96
# Token: stoß
#   Surprisal: 6.73
# Token: riegel
#   Surprisal: 23.56
# Token: Die
#   Surprisal: 17.84
# Token: Sonne
#   Surprisal: 10.43
# Token: scheint
#   Surprisal: 4.92
# Token: am
#   Surprisal: 3.85
# Token: blauen
#   Surprisal: 9.19
# Token: Himmel
#   Surprisal: 0.13
# Token: riegel
#   Surprisal: 28.62
# Token: Die
#   Surprisal: 17.84
# Token: Treppe
#   Surprisal: 13.74
# Token: führt
#   Surprisal: 5.96
# Token: ins
#   Surprisal: 4.58
# Token: k
#   Surprisal: 10.82
# Token: usch
#   Surprisal: 3.70
# Token: el
#   Surprisal: 0.02
# Token: ige
#   Surprisal: 0.12
# Token: Schlafzimmer
#   Surprisal: 3.82
# Token: riegel
#   Surprisal: 21.23
# Token: Das
#   Surprisal: 18.88
# Token: Fahrrad
#   Surprisal: 11.10
# Token: rollt
#   Surprisal: 8.43
# Token: leise
#   Surprisal: 10.36
# Token: über
#   Surprisal: 3.82
# Token: Kopf
#   Surprisal: 11.91
# Token: stein
#   Surprisal: 3.68
# Token: pflaster
#   Surprisal: 0.03
# Token: riegel
#   Surprisal: 19.57
# Token: Am
#   Surprisal: 19.10
# Token: blauen
#   Surprisal: 15.75
# Token: Himmel
#   Surprisal: 5.47
# Token: ziehen
#   Surprisal: 10.76
# Token: die
#   Surprisal: 2.37
# Token: Wolken
#   Surprisal: 3.90
# Token: riegel
#   Surprisal: 19.31
# Token: Sen
#   Surprisal: 23.43
# Token: ioren
#   Surprisal: 5.74
# Token: machen
#   Surprisal: 10.11
# Token: mor
#   Surprisal: 20.58
# Token: gend
#   Surprisal: 0.36
# Token: liche
#   Surprisal: 1.53
# Token: Gymnastik
#   Surprisal: 6.19
# Token: im
#   Surprisal: 4.93
# Token: Park
#   Surprisal: 5.28
# Token: riegel
#   Surprisal: 14.93
# Token: Ein
#   Surprisal: 18.19
# Token: primit
#   Surprisal: 17.10
# Token: iver
#   Surprisal: 1.47
# Token: Mensch
#   Surprisal: 5.76
# Token: wird
#   Surprisal: 6.27
# Token: keine
#   Surprisal: 8.36
# Token: Sch
#   Surprisal: 8.29
# Token: eu
#   Surprisal: 1.19
# Token: kennen
#   Surprisal: 9.19
# Token: riegel
#   Surprisal: 30.17
# Token: Wild
#   Surprisal: 23.50
# Token: pf
#   Surprisal: 18.24
# Token: eift
#   Surprisal: 2.66
# Token: der
#   Surprisal: 5.36
# Token: Wind
#   Surprisal: 4.22
# Token: durch
#   Surprisal: 5.66
# Token: die
#   Surprisal: 1.17
# Token: Wände
#   Surprisal: 8.91
# Token: riegel
#   Surprisal: 25.34
# Token: Fünf
#   Surprisal: 24.79
# Token: Film
#   Surprisal: 13.69
# Token: titel
#   Surprisal: 5.84
# Token: müssen
#   Surprisal: 9.64
# Token: wir
#   Surprisal: 6.05
# Token: auf
#   Surprisal: 5.91
# Token: schreiben
#   Surprisal: 3.89
# Token: riegel
#   Surprisal: 32.70
# Token: Die
#   Surprisal: 17.84
# Token: Freunde
#   Surprisal: 12.50
# Token: sch
#   Surprisal: 11.86
# Token: auten
#   Surprisal: 1.97
# Token: verwirrt
#   Surprisal: 12.28
# Token: auf
#   Surprisal: 3.66
# Token: ihr
#   Surprisal: 5.63
# Token: Getränk
#   Surprisal: 12.98
# Token: riegel
#   Surprisal: 23.90
# Token: Die
#   Surprisal: 17.84
# Token: Wolken
#   Surprisal: 13.65
# Token: malen
#   Surprisal: 16.25
# Token: Geschichten
#   Surprisal: 13.26
# Token: am
#   Surprisal: 8.78
# Token: Himmel
#   Surprisal: 0.89
# Token: riegel
#   Surprisal: 28.82
# Token: Die
#   Surprisal: 17.84
# Token: Freunde
#   Surprisal: 12.50
# Token: treffen
#   Surprisal: 10.58
# Token: sich
#   Surprisal: 0.73
# Token: am
#   Surprisal: 2.73
# Token: See
#   Surprisal: 10.28
# Token: riegel
#   Surprisal: 20.93
# Token: Es
#   Surprisal: 18.27
# Token: wird
#   Surprisal: 5.01
# Token: auch
#   Surprisal: 5.26
# Token: da
#   Surprisal: 10.26
# Token: chines
#   Surprisal: 18.54
# Token: isch
#   Surprisal: 0.27
# Token: gesprochen
#   Surprisal: 3.64
# Token: riegel
#   Surprisal: 31.54
# Token: Der
#   Surprisal: 18.26
# Token: Regenbogen
#   Surprisal: 16.11
# Token: endete
#   Surprisal: 16.22
# Token: im
#   Surprisal: 4.64
# Token: Bl
#   Surprisal: 11.97
# Token: ument
#   Surprisal: 1.02
# Token: opf
#   Surprisal: 0.10
# Token: riegel
#   Surprisal: 23.29
# Token: Die
#   Surprisal: 17.84
# Token: Melodie
#   Surprisal: 15.28
# Token: klingt
#   Surprisal: 7.97
# Token: nach
#   Surprisal: 5.20
# Token: Sommer
#   Surprisal: 9.98
# Token: riegel
#   Surprisal: 22.69
# Token: Fünf
#   Surprisal: 24.79
# Token: Freunde
#   Surprisal: 9.75
# Token: wollen
#   Surprisal: 8.16
# Token: die
#   Surprisal: 4.50
# Token: Welt
#   Surprisal: 2.99
# Token: ber
#   Surprisal: 7.06
# Token: eisen
#   Surprisal: 0.08
# Token: riegel
#   Surprisal: 30.25
# Token: Die
#   Surprisal: 17.84
# Token: Bä
#   Surprisal: 14.38
# Token: ck
#   Surprisal: 3.83
# Token: erin
#   Surprisal: 1.37
# Token: singt
#   Surprisal: 14.42
# Token: fröhlich
#   Surprisal: 8.95
# Token: beim
#   Surprisal: 9.45
# Token: Brötchen
#   Surprisal: 13.05
# Token: ba
#   Surprisal: 5.14
# Token: cken
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 27.53
# Token: L
#   Surprisal: 15.52
# Token: eise
#   Surprisal: 11.36
# Token: rollen
#   Surprisal: 15.11
# Token: wir
#   Surprisal: 5.24
# Token: aus
#   Surprisal: 7.83
# Token: dem
#   Surprisal: 1.91
# Token: Bahnhof
#   Surprisal: 6.91
# Token: riegel
#   Surprisal: 20.94
# Token: Wenn
#   Surprisal: 19.75
# Token: der
#   Surprisal: 5.09
# Token: Schnee
#   Surprisal: 8.99
# Token: schm
#   Surprisal: 4.79
# Token: il
#   Surprisal: 0.02
# Token: zt
#   Surprisal: 0.00
# Token: kommt
#   Surprisal: 9.28
# Token: der
#   Surprisal: 2.76
# Token: Frühling
#   Surprisal: 4.29
# Token: riegel
#   Surprisal: 28.54
# Token: Schul
#   Surprisal: 22.39
# Token: kinder
#   Surprisal: 7.09
# Token: müssen
#   Surprisal: 8.93
# Token: Rech
#   Surprisal: 18.47
# Token: nen
#   Surprisal: 0.67
# Token: und
#   Surprisal: 3.02
# Token: Schreiben
#   Surprisal: 1.70
# Token: lernen
#   Surprisal: 0.63
# Token: riegel
#   Surprisal: 27.84
# Token: Es
#   Surprisal: 18.27
# Token: gehört
#   Surprisal: 8.87
# Token: zu
#   Surprisal: 2.23
# Token: einer
#   Surprisal: 3.83
# Token: Feld
#   Surprisal: 13.69
# Token: sche
#   Surprisal: 7.75
# Token: une
#   Surprisal: 0.02
# Token: riegel
#   Surprisal: 23.49
# Token: Vor
#   Surprisal: 20.32
# Token: dem
#   Surprisal: 3.88
# Token: Fenster
#   Surprisal: 10.26
# Token: summ
#   Surprisal: 14.57
# Token: t
#   Surprisal: 0.39
# Token: eine
#   Surprisal: 3.82
# Token: kleine
#   Surprisal: 5.54
# Token: B
#   Surprisal: 8.17
# Token: iene
#   Surprisal: 0.40
# Token: riegel
#   Surprisal: 27.67
# Token: Engl
#   Surprisal: 27.12
# Token: ische
#   Surprisal: 1.57
# Token: Kriminal
#   Surprisal: 16.46
# Token: rom
#   Surprisal: 3.34
# Token: ane
#   Surprisal: 0.02
# Token: sind
#   Surprisal: 6.13
# Token: ihm
#   Surprisal: 11.42
# Token: die
#   Surprisal: 8.44
# Token: lieb
#   Surprisal: 9.43
# Token: ste
#   Surprisal: 2.27
# Token: Lektüre
#   Surprisal: 1.66
# Token: riegel
#   Surprisal: 21.63
# Token: Im
#   Surprisal: 18.80
# Token: Park
#   Surprisal: 10.99
# Token: traf
#   Surprisal: 13.62
# Token: ich
#   Surprisal: 4.18
# Token: meinen
#   Surprisal: 6.40
# Token: Deutsch
#   Surprisal: 12.03
# Token: lehrer
#   Surprisal: 0.60
# Token: riegel
#   Surprisal: 28.67
# Token: Mein
#   Surprisal: 21.27
# Token: Chef
#   Surprisal: 10.01
# Token: hat
#   Surprisal: 3.14
# Token: eine
#   Surprisal: 5.42
# Token: seltsame
#   Surprisal: 9.57
# Token: Fris
#   Surprisal: 9.31
# Token: ur
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 32.94
# Token: Danach
#   Surprisal: 24.45
# Token: tut
#   Surprisal: 12.87
# Token: eine
#   Surprisal: 9.24
# Token: Wanderung
#   Surprisal: 10.49
# Token: gut
#   Surprisal: 3.22
# Token: riegel
#   Surprisal: 26.70
# Token: Er
#   Surprisal: 20.51
# Token: gewinnt
#   Surprisal: 13.48
# Token: sechs
#   Surprisal: 10.33
# Token: Spiele
#   Surprisal: 3.31
# Token: nacheinander
#   Surprisal: 7.18
# Token: riegel
#   Surprisal: 35.48
# Token: Ein
#   Surprisal: 18.19
# Token: Bauer
#   Surprisal: 10.35
# Token: arbeitet
#   Surprisal: 9.32
# Token: auf
#   Surprisal: 4.16
# Token: seinem
#   Surprisal: 4.70
# Token: Acker
#   Surprisal: 2.89
# Token: riegel
#   Surprisal: 22.04
# Token: Sie
#   Surprisal: 18.28
# Token: isst
#   Surprisal: 13.44
# Token: kein
#   Surprisal: 6.71
# Token: s
#   Surprisal: 12.33
# Token: alz
#   Surprisal: 0.62
# Token: iges
#   Surprisal: 0.27
# Token: Gericht
#   Surprisal: 3.88
# Token: riegel
#   Surprisal: 18.87
# Token: Im
#   Surprisal: 18.80
# Token: Geschäft
#   Surprisal: 10.30
# Token: stehen
#   Surprisal: 9.30
# Token: viele
#   Surprisal: 5.88
# Token: Leute
#   Surprisal: 7.35
# Token: riegel
#   Surprisal: 26.63
# Token: Der
#   Surprisal: 18.26
# Token: Laptop
#   Surprisal: 15.21
# Token: sur
#   Surprisal: 15.76
# Token: ft
#   Surprisal: 2.53
# Token: schnell
#   Surprisal: 10.18
# Token: im
#   Surprisal: 4.99
# Token: Internet
#   Surprisal: 1.28
# Token: riegel
#   Surprisal: 22.08
# Token: Der
#   Surprisal: 18.26
# Token: Post
#   Surprisal: 11.40
# Token: bote
#   Surprisal: 2.57
# Token: liest
#   Surprisal: 9.87
# Token: Gedichte
#   Surprisal: 9.65
# Token: beim
#   Surprisal: 11.09
# Token: Zu
#   Surprisal: 9.71
# Token: stellen
#   Surprisal: 2.64
# Token: riegel
#   Surprisal: 26.60
# Token: Die
#   Surprisal: 17.84
# Token: Waschmaschine
#   Surprisal: 14.73
# Token: summ
#   Surprisal: 15.67
# Token: t
#   Surprisal: 0.44
# Token: sanft
#   Surprisal: 9.56
# Token: im
#   Surprisal: 4.75
# Token: Hintergrund
#   Surprisal: 3.71
# Token: riegel
#   Surprisal: 24.07
# Token: Der
#   Surprisal: 18.26
# Token: Löwe
#   Surprisal: 12.97
# Token: sch
#   Surprisal: 9.59
# Token: leicht
#   Surprisal: 2.21
# Token: im
#   Surprisal: 4.28
# Token: Käfig
#   Surprisal: 8.15
# Token: umher
#   Surprisal: 2.46
# Token: riegel
#   Surprisal: 27.48
# Token: Vor
#   Surprisal: 20.32
# Token: dem
#   Surprisal: 3.88
# Token: Haus
#   Surprisal: 8.06
# Token: bl
#   Surprisal: 12.12
# Token: ühen
#   Surprisal: 1.80
# Token: bunte
#   Surprisal: 7.50
# Token: Blumen
#   Surprisal: 2.62
# Token: be
#   Surprisal: 8.75
# Token: ete
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 28.71
# Token: Ste
#   Surprisal: 20.11
# Token: hend
#   Surprisal: 6.06
# Token: macht
#   Surprisal: 14.18
# Token: man
#   Surprisal: 5.09
# Token: seine
#   Surprisal: 8.65
# Token: Aussage
#   Surprisal: 10.05
# Token: riegel
#   Surprisal: 23.92
# Token: Die
#   Surprisal: 17.84
# Token: Verkä
#   Surprisal: 15.29
# Token: uferin
#   Surprisal: 0.05
# Token: hat
#   Surprisal: 4.59
# Token: einen
#   Surprisal: 4.74
# Token: ungewöhnlichen
#   Surprisal: 8.11
# Token: Akzent
#   Surprisal: 11.07
# Token: riegel
#   Surprisal: 27.54
# Token: Die
#   Surprisal: 17.84
# Token: letzt
#   Surprisal: 15.99
# Token: malige
#   Surprisal: 3.36
# Token: Feststellung
#   Surprisal: 9.33
# Token: war
#   Surprisal: 9.96
# Token: eindrucksvoll
#   Surprisal: 12.12
# Token: riegel
#   Surprisal: 30.37
# Token: Sein
#   Surprisal: 20.84
# Token: Singen
#   Surprisal: 16.49
# Token: erfüllte
#   Surprisal: 12.71
# Token: den
#   Surprisal: 3.55
# Token: stillen
#   Surprisal: 8.31
# Token: Wald
#   Surprisal: 8.03
# Token: riegel
#   Surprisal: 14.97
# Token: Die
#   Surprisal: 17.84
# Token: Katze
#   Surprisal: 12.67
# Token: schläft
#   Surprisal: 10.04
# Token: auf
#   Surprisal: 5.36
# Token: dem
#   Surprisal: 1.16
# Token: Sofa
#   Surprisal: 3.13
# Token: riegel
#   Surprisal: 25.04
# Token: In
#   Surprisal: 16.59
# Token: der
#   Surprisal: 5.12
# Token: Bucht
#   Surprisal: 11.35
# Token: gl
#   Surprisal: 16.62
# Token: itz
#   Surprisal: 3.06
# Token: ern
#   Surprisal: 0.86
# Token: die
#   Surprisal: 1.66
# Token: silbernen
#   Surprisal: 10.67
# Token: Wellen
#   Surprisal: 4.14
# Token: riegel
#   Surprisal: 19.25
# Token: Geld
#   Surprisal: 27.67
# Token: allein
#   Surprisal: 14.35
# Token: macht
#   Surprisal: 6.60
# Token: nicht
#   Surprisal: 4.02
# Token: glücklich
#   Surprisal: 3.02
# Token: riegel
#   Surprisal: 28.88
# Token: Auf
#   Surprisal: 20.57
# Token: dem
#   Surprisal: 3.50
# Token: Gehweg
#   Surprisal: 10.01
# Token: quiet
#   Surprisal: 14.92
# Token: schen
#   Surprisal: 0.88
# Token: Kinder
#   Surprisal: 7.10
# Token: fahr
#   Surprisal: 15.85
# Token: räder
#   Surprisal: 0.31
# Token: riegel
#   Surprisal: 25.74
# Token: Zum
#   Surprisal: 21.64
# Token: Ausweis
#   Surprisal: 17.38
# Token: gehört
#   Surprisal: 8.88
# Token: ein
#   Surprisal: 3.17
# Token: Licht
#   Surprisal: 7.66
# Token: bild
#   Surprisal: 0.79
# Token: riegel
#   Surprisal: 18.06
# Token: Der
#   Surprisal: 18.26
# Token: Pfl
#   Surprisal: 15.62
# Token: ug
#   Surprisal: 0.96
# Token: zieht
#   Surprisal: 8.38
# Token: tiefe
#   Surprisal: 15.85
# Token: F
#   Surprisal: 7.29
# Token: urch
#   Surprisal: 0.03
# Token: en
#   Surprisal: 0.05
# Token: riegel
#   Surprisal: 22.09
# Token: Ein
#   Surprisal: 18.19
# Token: Künstler
#   Surprisal: 11.98
# Token: malt
#   Surprisal: 9.00
# Token: Porträts
#   Surprisal: 7.47
# Token: auf
#   Surprisal: 4.60
# Token: dem
#   Surprisal: 3.80
# Token: Marktplatz
#   Surprisal: 9.22
# Token: riegel
#   Surprisal: 26.34
# Token: Vater
#   Surprisal: 28.33
# Token: mischt
#   Surprisal: 16.32
# Token: gleich
#   Surprisal: 10.80
# Token: die
#   Surprisal: 4.62
# Token: Karten
#   Surprisal: 9.83
# Token: riegel
#   Surprisal: 27.83
# Token: Der
#   Surprisal: 18.26
# Token: Kellner
#   Surprisal: 14.23
# Token: j
#   Surprisal: 11.93
# Token: on
#   Surprisal: 4.00
# Token: gl
#   Surprisal: 0.13
# Token: iert
#   Surprisal: 0.26
# Token: mit
#   Surprisal: 2.28
# Token: den
#   Surprisal: 4.36
# Token: Speise
#   Surprisal: 10.80
# Token: karten
#   Surprisal: 0.64
# Token: riegel
#   Surprisal: 26.43
# Token: Im
#   Surprisal: 18.80
# Token: Meer
#   Surprisal: 11.92
# Token: t
#   Surprisal: 7.69
# Token: ummeln
#   Surprisal: 0.88
# Token: sich
#   Surprisal: 0.14
# Token: faszinierende
#   Surprisal: 12.11
# Token: Lebens
#   Surprisal: 11.60
# Token: formen
#   Surprisal: 0.95
# Token: riegel
#   Surprisal: 28.13
# Token: Ein
#   Surprisal: 18.19
# Token: älter
#   Surprisal: 12.81
# Token: es
#   Surprisal: 0.21
# Token: Paar
#   Surprisal: 3.68
# Token: sp
#   Surprisal: 9.59
# Token: az
#   Surprisal: 0.54
# Token: iert
#   Surprisal: 2.14
# Token: Hand
#   Surprisal: 16.63
# Token: in
#   Surprisal: 0.06
# Token: Hand
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 23.46
# Token: Vor
#   Surprisal: 20.32
# Token: der
#   Surprisal: 4.49
# Token: Hütte
#   Surprisal: 10.66
# Token: sitzt
#   Surprisal: 10.49
# Token: ein
#   Surprisal: 2.05
# Token: großer
#   Surprisal: 7.31
# Token: Heu
#   Surprisal: 11.62
# Token: haufen
#   Surprisal: 3.42
# Token: riegel
#   Surprisal: 22.43
# Token: Autos
#   Surprisal: 27.05
# Token: fahren
#   Surprisal: 10.19
# Token: auf
#   Surprisal: 6.09
# Token: der
#   Surprisal: 1.75
# Token: Straße
#   Surprisal: 3.52
# Token: riegel
#   Surprisal: 27.19
# Token: Der
#   Surprisal: 18.26
# Token: Kaffee
#   Surprisal: 12.96
# Token: pl
#   Surprisal: 13.83
# Token: ausch
#   Surprisal: 3.12
# Token: wurde
#   Surprisal: 6.42
# Token: von
#   Surprisal: 3.34
# Token: Ameisen
#   Surprisal: 17.33
# Token: gestört
#   Surprisal: 5.34
# Token: riegel
#   Surprisal: 33.27
# Token: Der
#   Surprisal: 18.26
# Token: Fernseher
#   Surprisal: 13.36
# Token: spielt
#   Surprisal: 7.88
# Token: eigen
#   Surprisal: 14.63
# Token: willige
#   Surprisal: 6.74
# Token: Liebes
#   Surprisal: 10.94
# Token: filme
#   Surprisal: 6.34
# Token: riegel
#   Surprisal: 29.93
# Token: Beim
#   Surprisal: 23.09
# Token: Studien
#   Surprisal: 14.08
# Token: kurs
#   Surprisal: 10.15
# Token: musst
#   Surprisal: 12.60
# Token: Du
#   Surprisal: 2.56
# Token: ernsthaft
#   Surprisal: 13.69
# Token: lernen
#   Surprisal: 4.87
# Token: riegel
#   Surprisal: 30.47
# Token: Vater
#   Surprisal: 28.33
# Token: will
#   Surprisal: 10.13
# Token: sich
#   Surprisal: 4.24
# Token: eine
#   Surprisal: 7.33
# Token: Pf
#   Surprisal: 12.58
# Token: eife
#   Surprisal: 1.17
# Token: an
#   Surprisal: 4.66
# Token: z
#   Surprisal: 2.74
# Token: ünden
#   Surprisal: 0.16
# Token: riegel
#   Surprisal: 31.23
# Token: Im
#   Surprisal: 18.80
# Token: Gebirge
#   Surprisal: 12.88
# Token: gl
#   Surprisal: 14.57
# Token: itz
#   Surprisal: 4.92
# Token: ern
#   Surprisal: 0.87
# Token: die
#   Surprisal: 1.70
# Token: schne
#   Surprisal: 7.68
# Token: ebe
#   Surprisal: 0.28
# Token: deckten
#   Surprisal: 0.02
# Token: Gipfel
#   Surprisal: 1.32
# Token: riegel
#   Surprisal: 17.88
# Token: Ö
#   Surprisal: 18.46
# Token: fen
#   Surprisal: 6.93
# Token: brauchen
#   Surprisal: 14.03
# Token: Kohlen
#   Surprisal: 12.16
# Token: und
#   Surprisal: 7.51
# Token: Br
#   Surprisal: 7.53
# Token: ik
#   Surprisal: 0.02
# Token: etts
#   Surprisal: 0.05
# Token: riegel
#   Surprisal: 24.65
# Token: Die
#   Surprisal: 17.84
# Token: Hilfs
#   Surprisal: 13.11
# Token: mannschaft
#   Surprisal: 9.41
# Token: setzt
#   Surprisal: 8.93
# Token: sich
#   Surprisal: 0.86
# Token: in
#   Surprisal: 5.90
# Token: Marsch
#   Surprisal: 8.97
# Token: riegel
#   Surprisal: 21.78
# Token: In
#   Surprisal: 16.59
# Token: der
#   Surprisal: 5.12
# Token: Galerie
#   Surprisal: 10.62
# Token: bewundern
#   Surprisal: 14.46
# Token: Besucher
#   Surprisal: 8.44
# Token: zeitgenössische
#   Surprisal: 11.58
# Token: Kunst
#   Surprisal: 1.90
# Token: riegel
#   Surprisal: 23.72
# Token: Auf
#   Surprisal: 20.57
# Token: dem
#   Surprisal: 3.50
# Token: Dach
#   Surprisal: 5.51
# Token: singt
#   Surprisal: 17.36
# Token: fröhlich
#   Surprisal: 13.82
# Token: ein
#   Surprisal: 2.61
# Token: Vogel
#   Surprisal: 6.17
# Token: riegel
#   Surprisal: 19.24
# Token: Fl
#   Surprisal: 22.61
# Token: üst
#   Surprisal: 10.46
# Token: ernd
#   Surprisal: 4.18
# Token: erzählt
#   Surprisal: 7.83
# Token: der
#   Surprisal: 3.30
# Token: Wind
#   Surprisal: 12.68
# Token: Geschichten
#   Surprisal: 10.86
# Token: riegel
#   Surprisal: 28.68
# Token: Der
#   Surprisal: 18.26
# Token: Kamin
#   Surprisal: 13.85
# Token: verbreitet
#   Surprisal: 15.65
# Token: wohl
#   Surprisal: 8.36
# Token: ige
#   Surprisal: 4.87
# Token: Wärme
#   Surprisal: 0.50
# Token: riegel
#   Surprisal: 25.49
# Token: Unsere
#   Surprisal: 23.86
# Token: beiden
#   Surprisal: 13.05
# Token: Hunde
#   Surprisal: 10.66
# Token: haben
#   Surprisal: 4.23
# Token: Durst
#   Surprisal: 12.09
# Token: riegel
#   Surprisal: 22.92
# Token: Im
#   Surprisal: 18.80
# Token: Dschungel
#   Surprisal: 11.38
# Token: herrscht
#   Surprisal: 12.41
# Token: sk
#   Surprisal: 14.59
# Token: rup
#   Surprisal: 3.58
# Token: ell
#   Surprisal: 0.23
# Token: ose
#   Surprisal: 1.43
# Token: Lebens
#   Surprisal: 9.49
# Token: form
#   Surprisal: 6.14
# Token: riegel
#   Surprisal: 25.76
# Token: Die
#   Surprisal: 17.84
# Token: Freunde
#   Surprisal: 12.50
# Token: teilen
#   Surprisal: 14.04
# Token: Geschichten
#   Surprisal: 11.25
# Token: am
#   Surprisal: 9.83
# Token: Lager
#   Surprisal: 6.91
# Token: feuer
#   Surprisal: 0.01
# Token: riegel
#   Surprisal: 28.33
# Token: Nach
#   Surprisal: 19.36
# Token: einer
#   Surprisal: 4.49
# Token: Umfrage
#   Surprisal: 7.95
# Token: kennt
#   Surprisal: 15.79
# Token: niemand
#   Surprisal: 6.64
# Token: dieses
#   Surprisal: 9.43
# Token: Fremd
#   Surprisal: 15.03
# Token: wort
#   Surprisal: 0.50
# Token: riegel
#   Surprisal: 23.38
# Token: Der
#   Surprisal: 18.26
# Token: Nachbar
#   Surprisal: 12.16
# Token: trägt
#   Surprisal: 10.70
# Token: heute
#   Surprisal: 9.62
# Token: einen
#   Surprisal: 4.27
# Token: bunten
#   Surprisal: 9.38
# Token: Anzug
#   Surprisal: 5.54
# Token: riegel
#   Surprisal: 27.32
# Token: Acht
#   Surprisal: 23.51
# Token: los
#   Surprisal: 6.96
# Token: wirft
#   Surprisal: 11.59
# Token: der
#   Surprisal: 3.64
# Token: Kn
#   Surprisal: 12.55
# Token: ir
#   Surprisal: 1.26
# Token: ps
#   Surprisal: 0.02
# Token: Mat
#   Surprisal: 15.31
# Token: sch
#   Surprisal: 3.51
# Token: durchs
#   Surprisal: 8.30
# Token: Eck
#   Surprisal: 10.44
# Token: fenster
#   Surprisal: 5.72
# Token: riegel
#   Surprisal: 24.40
# Token: Der
#   Surprisal: 18.26
# Token: Bus
#   Surprisal: 10.55
# Token: fährt
#   Surprisal: 4.53
# Token: durch
#   Surprisal: 5.48
# Token: die
#   Surprisal: 1.52
# Token: Stadt
#   Surprisal: 3.69
# Token: riegel
#   Surprisal: 20.57
# Token: Die
#   Surprisal: 17.84
# Token: Straßen
#   Surprisal: 11.64
# Token: l
#   Surprisal: 7.04
# Token: ater
#   Surprisal: 0.18
# Token: nen
#   Surprisal: 0.02
# Token: leuchten
#   Surprisal: 6.86
# Token: im
#   Surprisal: 4.46
# Token: Abend
#   Surprisal: 8.26
# Token: ne
#   Surprisal: 6.96
# Token: bel
#   Surprisal: 0.01
# Token: riegel
#   Surprisal: 26.70
# Token: Der
#   Surprisal: 18.26
# Token: Fluss
#   Surprisal: 12.37
# Token: pl
#   Surprisal: 12.21
# Token: ät
#   Surprisal: 0.31
# Token: sch
#   Surprisal: 0.04
# Token: ert
#   Surprisal: 0.38
# Token: sanft
#   Surprisal: 12.27
# Token: durch
#   Surprisal: 5.10
# Token: das
#   Surprisal: 2.84
# Token: Tal
#   Surprisal: 5.24
# Token: riegel
#   Surprisal: 19.98
# Token: Kollegen
#   Surprisal: 26.83
# Token: feiern
#   Surprisal: 11.19
# Token: den
#   Surprisal: 4.70
# Token: Abschluss
#   Surprisal: 6.19
# Token: eines
#   Surprisal: 5.89
# Token: erfolgreichen
#   Surprisal: 6.15
# Token: Projekts
#   Surprisal: 6.96
# Token: riegel
#   Surprisal: 26.40
# Token: Ä
#   Surprisal: 19.77
# Token: ng
#   Surprisal: 6.36
# Token: st
#   Surprisal: 2.93
# Token: lich
#   Surprisal: 9.71
# Token: beg
#   Surprisal: 12.23
# Token: reif
#   Surprisal: 5.19
# Token: st
#   Surprisal: 6.30
# Token: du
#   Surprisal: 3.20
# Token: O
#   Surprisal: 15.28
# Token: mas
#   Surprisal: 7.82
# Token: Lage
#   Surprisal: 11.17
# Token: riegel
#   Surprisal: 24.56
# Token: Die
#   Surprisal: 17.84
# Token: Tom
#   Surprisal: 14.40
# Token: ate
#   Surprisal: 4.12
# Token: im
#   Surprisal: 6.42
# Token: Kühlschrank
#   Surprisal: 4.93
# Token: k
#   Surprisal: 7.48
# Token: eim
#   Surprisal: 6.08
# Token: te
#   Surprisal: 6.22
# Token: riegel
#   Surprisal: 26.05
# Token: N
#   Surprisal: 15.21
# Token: erv
#   Surprisal: 11.19
# Token: öse
#   Surprisal: 9.07
# Token: Menschen
#   Surprisal: 8.73
# Token: brauchen
#   Surprisal: 7.36
# Token: viel
#   Surprisal: 6.06
# Token: Ruhe
#   Surprisal: 4.22
# Token: riegel
#   Surprisal: 23.38
# Token: Am
#   Surprisal: 19.10
# Token: Samstag
#   Surprisal: 5.41
# Token: öffnet
#   Surprisal: 9.49
# Token: der
#   Surprisal: 2.42
# Token: Kiosk
#   Surprisal: 9.99
# Token: erstmals
#   Surprisal: 9.75
# Token: riegel
#   Surprisal: 34.01
# Token: Das
#   Surprisal: 18.88
# Token: Echo
#   Surprisal: 12.60
# Token: trägt
#   Surprisal: 12.86
# Token: Gedichte
#   Surprisal: 15.49
# Token: fort
#   Surprisal: 11.56
# Token: riegel
#   Surprisal: 26.16
# Token: Das
#   Surprisal: 18.88
# Token: Baby
#   Surprisal: 11.78
# Token: l
#   Surprisal: 12.55
# Token: achte
#   Surprisal: 4.04
# Token: über
#   Surprisal: 5.50
# Token: die
#   Surprisal: 2.01
# Token: f
#   Surprisal: 9.42
# Token: liegenden
#   Surprisal: 4.34
# Token: Luft
#   Surprisal: 11.17
# Token: ball
#   Surprisal: 0.32
# Token: ons
#   Surprisal: 0.08
# Token: riegel
#   Surprisal: 27.52
# Token: Seine
#   Surprisal: 22.60
# Token: Frau
#   Surprisal: 7.11
# Token: macht
#   Surprisal: 8.62
# Token: ein
#   Surprisal: 5.90
# Token: traur
#   Surprisal: 6.92
# Token: iges
#   Surprisal: 0.01
# Token: Gesicht
#   Surprisal: 0.68
# Token: riegel
#   Surprisal: 33.73
# Token: Die
#   Surprisal: 17.84
# Token: Tür
#   Surprisal: 11.62
# Token: kn
#   Surprisal: 10.81
# Token: arrt
#   Surprisal: 0.79
# Token: laut
#   Surprisal: 5.46
# Token: beim
#   Surprisal: 10.58
# Token: Öffnen
#   Surprisal: 6.65
# Token: riegel
#   Surprisal: 23.15
# Token: Der
#   Surprisal: 18.26
# Token: Fernseher
#   Surprisal: 13.36
# Token: zeigt
#   Surprisal: 7.37
# Token: die
#   Surprisal: 3.48
# Token: Nachrichten
#   Surprisal: 7.87
# Token: riegel
#   Surprisal: 25.34
# Token: Die
#   Surprisal: 17.84
# Token: Lampe
#   Surprisal: 16.57
# Token: sp
#   Surprisal: 11.05
# Token: endet
#   Surprisal: 3.05
# Token: angenehm
#   Surprisal: 10.29
# Token: es
#   Surprisal: 5.97
# Token: hell
#   Surprisal: 9.39
# Token: es
#   Surprisal: 0.24
# Token: Licht
#   Surprisal: 0.24
# Token: riegel
#   Surprisal: 28.38
# Token: Diese
#   Surprisal: 21.25
# Token: z
#   Surprisal: 12.44
# Token: arten
#   Surprisal: 5.19
# Token: Blumen
#   Surprisal: 6.39
# Token: wel
#   Surprisal: 13.41
# Token: ken
#   Surprisal: 0.25
# Token: rasch
#   Surprisal: 9.50
# Token: riegel
#   Surprisal: 28.74
# Token: Seine
#   Surprisal: 22.60
# Token: Worte
#   Surprisal: 6.67
# Token: schw
#   Surprisal: 11.50
# Token: eb
#   Surprisal: 5.84
# Token: ten
#   Surprisal: 0.01
# Token: wie
#   Surprisal: 6.77
# Token: Schmetter
#   Surprisal: 9.88
# Token: linge
#   Surprisal: 0.07
# Token: riegel
#   Surprisal: 32.89
# Token: Die
#   Surprisal: 17.84
# Token: Gärtner
#   Surprisal: 14.14
# Token: in
#   Surprisal: 3.47
# Token: tanzt
#   Surprisal: 10.66
# Token: zwischen
#   Surprisal: 8.78
# Token: den
#   Surprisal: 1.64
# Token: Blumen
#   Surprisal: 4.40
# Token: be
#   Surprisal: 8.07
# Token: eten
#   Surprisal: 0.06
# Token: riegel
#   Surprisal: 26.74
# Token: Der
#   Surprisal: 18.26
# Token: Mond
#   Surprisal: 11.13
# Token: schein
#   Surprisal: 10.97
# Token: taucht
#   Surprisal: 10.27
# Token: die
#   Surprisal: 5.52
# Token: Landschaft
#   Surprisal: 7.80
# Token: in
#   Surprisal: 2.80
# Token: Silber
#   Surprisal: 12.71
# Token: riegel
#   Surprisal: 23.20
# Token: Das
#   Surprisal: 18.88
# Token: Buch
#   Surprisal: 8.46
# Token: liegt
#   Surprisal: 7.07
# Token: auf
#   Surprisal: 2.87
# Token: dem
#   Surprisal: 0.86
# Token: gemütlichen
#   Surprisal: 14.00
# Token: Sofa
#   Surprisal: 1.30
# Token: riegel
#   Surprisal: 25.23
# Token: Ad
#   Surprisal: 20.07
# Token: ler
#   Surprisal: 4.84
# Token: fliegen
#   Surprisal: 11.63
# Token: tausend
#   Surprisal: 16.85
# Token: Meter
#   Surprisal: 8.63
# Token: hoch
#   Surprisal: 5.70
# Token: riegel
#   Surprisal: 27.20
# Token: M
#   Surprisal: 14.79
# Token: esser
#   Surprisal: 10.83
# Token: und
#   Surprisal: 5.44
# Token: Gabel
#   Surprisal: 6.28
# Token: liegen
#   Surprisal: 11.01
# Token: neben
#   Surprisal: 8.32
# Token: dem
#   Surprisal: 1.65
# Token: Teller
#   Surprisal: 8.18
# Token: riegel
#   Surprisal: 14.46
# Token: Die
#   Surprisal: 17.84
# Token: Familie
#   Surprisal: 9.84
# Token: genießt
#   Surprisal: 10.47
# Token: gemeinsames
#   Surprisal: 17.31
# Token: Abendessen
#   Surprisal: 7.53
# Token: riegel
#   Surprisal: 27.95
# Token: Ein
#   Surprisal: 18.19
# Token: älter
#   Surprisal: 12.81
# Token: es
#   Surprisal: 0.21
# Token: Ehepaar
#   Surprisal: 2.16
# Token: tanzt
#   Surprisal: 13.63
# Token: auf
#   Surprisal: 3.51
# Token: der
#   Surprisal: 1.91
# Token: Hochzeits
#   Surprisal: 8.84
# Token: feier
#   Surprisal: 1.21
# Token: riegel
#   Surprisal: 29.49
# Token: Die
#   Surprisal: 17.84
# Token: Hochzeit
#   Surprisal: 11.67
# Token: versammelt
#   Surprisal: 18.47
# Token: Familie
#   Surprisal: 9.02
# Token: und
#   Surprisal: 1.52
# Token: Freunde
#   Surprisal: 1.11
# Token: riegel
#   Surprisal: 31.44
# Token: Ein
#   Surprisal: 18.19
# Token: ruhiger
#   Surprisal: 13.52
# Token: Bach
#   Surprisal: 9.39
# Token: pl
#   Surprisal: 13.13
# Token: ät
#   Surprisal: 0.06
# Token: sch
#   Surprisal: 0.10
# Token: ert
#   Surprisal: 0.12
# Token: durch
#   Surprisal: 2.94
# Token: den
#   Surprisal: 2.18
# Token: Wald
#   Surprisal: 1.43
# Token: riegel
#   Surprisal: 18.04
# Token: Jeden
#   Surprisal: 25.46
# Token: Freitag
#   Surprisal: 3.56
# Token: gibt
#   Surprisal: 4.90
# Token: 's
#   Surprisal: 5.28
# Token: frischen
#   Surprisal: 9.41
# Token: Fisch
#   Surprisal: 4.03
# Token: riegel
#   Surprisal: 20.66
# Token: Diese
#   Surprisal: 21.25
# Token: Mannschaft
#   Surprisal: 12.68
# Token: schoss
#   Surprisal: 11.14
# Token: gleich
#   Surprisal: 7.46
# Token: drei
#   Surprisal: 2.13
# Token: Tore
#   Surprisal: 0.83
# Token: riegel
#   Surprisal: 26.61
# Token: Sch
#   Surprisal: 16.99
# Token: nu
#   Surprisal: 8.40
# Token: pfen
#   Surprisal: 2.88
# Token: stört
#   Surprisal: 15.34
# Token: uns
#   Surprisal: 6.91
# Token: natürlich
#   Surprisal: 7.31
# Token: sehr
#   Surprisal: 5.68
# Token: riegel
#   Surprisal: 33.40
# Token: Nicht
#   Surprisal: 22.55
# Token: jeder
#   Surprisal: 13.03
# Token: vert
#   Surprisal: 14.87
# Token: rägt
#   Surprisal: 0.03
# Token: kalt
#   Surprisal: 13.66
# Token: es
#   Surprisal: 0.14
# Token: Bier
#   Surprisal: 4.44
# Token: riegel
#   Surprisal: 23.03
# Token: Der
#   Surprisal: 18.26
# Token: Hund
#   Surprisal: 10.68
# Token: be
#   Surprisal: 6.77
# Token: llt
#   Surprisal: 0.31
# Token: vor
#   Surprisal: 6.54
# Token: dem
#   Surprisal: 4.00
# Token: Haus
#   Surprisal: 3.25
# Token: riegel
#   Surprisal: 16.86
# Token: Der
#   Surprisal: 18.26
# Token: gelbe
#   Surprisal: 13.16
# Token: Küchen
#   Surprisal: 16.87
# Token: ofen
#   Surprisal: 9.11
# Token: sorgt
#   Surprisal: 7.04
# Token: für
#   Surprisal: 1.13
# Token: Wärme
#   Surprisal: 4.16
# Token: riegel
#   Surprisal: 23.26
# Token: Das
#   Surprisal: 18.88
# Token: war
#   Surprisal: 5.21
# Token: jetzt
#   Surprisal: 8.36
# Token: aber
#   Surprisal: 4.85
# Token: ein
#   Surprisal: 3.80
# Token: schöner
#   Surprisal: 7.32
# Token: Tag
#   Surprisal: 3.28
# Token: riegel
#   Surprisal: 29.32
# Token: Das
#   Surprisal: 18.88
# Token: Licht
#   Surprisal: 11.15
# Token: tanz
#   Surprisal: 15.83
# Token: te
#   Surprisal: 0.66
# Token: über
#   Surprisal: 5.22
# Token: dem
#   Surprisal: 3.97
# Token: Fluss
#   Surprisal: 8.70
# Token: riegel
#   Surprisal: 20.31
# Token: Studenten
#   Surprisal: 27.85
# Token: treffen
#   Surprisal: 10.22
# Token: sich
#   Surprisal: 0.48
# Token: in
#   Surprisal: 2.95
# Token: der
#   Surprisal: 2.14
# Token: Bibliothek
#   Surprisal: 7.13
# Token: riegel
#   Surprisal: 25.26
# Token: Mein
#   Surprisal: 21.27
# Token: Arzt
#   Surprisal: 11.34
# Token: empfahl
#   Surprisal: 8.66
# Token: dringend
#   Surprisal: 10.15
# Token: Bäder
#   Surprisal: 15.51
# Token: riegel
#   Surprisal: 22.82
# Token: Die
#   Surprisal: 17.84
# Token: Kaffe
#   Surprisal: 14.25
# Token: et
#   Surprisal: 2.90
# Token: asse
#   Surprisal: 0.81
# Token: kl
#   Surprisal: 10.20
# Token: irrt
#   Surprisal: 2.87
# Token: beim
#   Surprisal: 11.47
# Token: Frühstück
#   Surprisal: 5.48
# Token: riegel
#   Surprisal: 19.62
# Token: Diese
#   Surprisal: 21.25
# Token: Gegend
#   Surprisal: 12.17
# Token: nennt
#   Surprisal: 11.64
# Token: man
#   Surprisal: 0.25
# Token: Sand
#   Surprisal: 12.94
# Token: w
#   Surprisal: 4.28
# Token: üste
#   Surprisal: 0.36
# Token: riegel
#   Surprisal: 26.32
# Token: Vor
#   Surprisal: 20.32
# Token: dem
#   Surprisal: 3.88
# Token: Schloss
#   Surprisal: 9.11
# Token: wartet
#   Surprisal: 8.21
# Token: eine
#   Surprisal: 2.90
# Token: ein
#   Surprisal: 11.24
# Token: same
#   Surprisal: 0.42
# Token: Gestalt
#   Surprisal: 9.94
# Token: riegel
# ...
#   Surprisal: 14.44
# Token: form
#   Surprisal: 16.53
# Token: te
#   Surprisal: 3.16
# Token: die
#   Surprisal: 2.60
# Token: Vielfalt
#   Surprisal: 10.80
# Token: des
#   Surprisal: 3.60
# Token: Tier
#   Surprisal: 5.94
# Token: reichs
#   Surprisal: 1.24
# Token: entscheidend
#   Surprisal: 9.22
# Token: riegel
#   Surprisal: 29.04
# Token: Der
#   Surprisal: 18.26
# Token: Karls
#   Surprisal: 14.90
# Token: preis
#   Surprisal: 3.89
# Token: ist
#   Surprisal: 2.92
# Token: die
#   Surprisal: 3.87
# Token: Stern
#   Surprisal: 17.60
# Token: stunde
#   Surprisal: 3.66
# Token: eines
#   Surprisal: 5.09
# Token: Films
#   Surprisal: 12.13
# Token: riegel
#   Surprisal: 23.53
# Token: Der
#   Surprisal: 18.26
# Token: Spiegel
#   Surprisal: 11.49
# Token: reflektiert
#   Surprisal: 12.05
# Token: Träume
#   Surprisal: 16.73
# Token: die
#   Surprisal: 9.89
# Token: noch
#   Surprisal: 6.97
# Token: nicht
#   Surprisal: 3.56
# Token: geträumt
#   Surprisal: 9.32
# Token: wurden
#   Surprisal: 1.07
# Token: riegel
#   Surprisal: 31.90
# Token: Beim
#   Surprisal: 23.09
# Token: Kochen
#   Surprisal: 10.00
# Token: improvis
#   Surprisal: 14.88
# Token: iere
#   Surprisal: 3.93
# Token: ich
#   Surprisal: 0.05
# Token: gerne
#   Surprisal: 5.75
# Token: mit
#   Surprisal: 3.54
# Token: Gewür
#   Surprisal: 8.90
# Token: zen
#   Surprisal: 0.15
# Token: riegel
#   Surprisal: 24.03
# Token: Beim
#   Surprisal: 23.09
# Token: Kochen
#   Surprisal: 10.00
# Token: fiel
#   Surprisal: 13.25
# Token: mir
#   Surprisal: 2.35
# Token: ein
#   Surprisal: 2.39
# Token: Gedicht
#   Surprisal: 11.84
# Token: über
#   Surprisal: 6.37
# Token: Kartoffeln
#   Surprisal: 12.04
# Token: ein
#   Surprisal: 1.04
# Token: riegel
#   Surprisal: 31.72
# Token: Die
#   Surprisal: 17.84
# Token: Wüste
#   Surprisal: 13.64
# Token: erstreckte
#   Surprisal: 15.13
# Token: sich
#   Surprisal: 0.01
# Token: end
#   Surprisal: 12.33
# Token: los
#   Surprisal: 0.05
# Token: bis
#   Surprisal: 5.88
# Token: zum
#   Surprisal: 1.82
# Token: Horizont
#   Surprisal: 4.93
# Token: riegel
#   Surprisal: 26.88
# Token: Ein
#   Surprisal: 18.19
# Token: geheimnis
#   Surprisal: 15.02
# Token: volles
#   Surprisal: 2.17
# Token: Tagebuch
#   Surprisal: 8.48
# Token: liegt
#   Surprisal: 8.46
# Token: offen
#   Surprisal: 10.19
# Token: im
#   Surprisal: 3.39
# Token: verst
#   Surprisal: 10.45
# Token: aub
#   Surprisal: 0.67
# Token: ten
#   Surprisal: 0.00
# Token: Bücher
#   Surprisal: 6.27
# Token: reg
#   Surprisal: 0.41
# Token: al
#   Surprisal: 0.02
# Token: riegel
#   Surprisal: 25.52
# Token: Das
#   Surprisal: 18.88
# Token: geheimnis
#   Surprisal: 14.99
# Token: volle
#   Surprisal: 0.08
# Token: Buch
#   Surprisal: 6.57
# Token: entf
#   Surprisal: 17.50
# Token: ess
#   Surprisal: 6.92
# Token: elte
#   Surprisal: 0.25
# Token: die
#   Surprisal: 4.19
# Token: Kraft
#   Surprisal: 9.30
# Token: der
#   Surprisal: 1.65
# Token: Magie
#   Surprisal: 6.80
# Token: riegel
#   Surprisal: 26.29
# Token: Am
#   Surprisal: 19.10
# Token: Wochenende
#   Surprisal: 7.54
# Token: besuchen
#   Surprisal: 12.56
# Token: wir
#   Surprisal: 5.18
# Token: oft
#   Surprisal: 8.89
# Token: unsere
#   Surprisal: 4.73
# Token: Großeltern
#   Surprisal: 5.25
# Token: riegel
#   Surprisal: 22.94
# Token: Im
#   Surprisal: 18.80
# Token: alten
#   Surprisal: 12.42
# Token: Buch
#   Surprisal: 10.12
# Token: laden
#   Surprisal: 4.11
# Token: fand
#   Surprisal: 8.23
# Token: ich
#   Surprisal: 3.32
# Token: eine
#   Surprisal: 3.69
# Token: vergessen
#   Surprisal: 12.90
# Token: e
#   Surprisal: 0.01
# Token: Sammlung
#   Surprisal: 7.91
# Token: von
#   Surprisal: 1.40
# Token: Gedichten
#   Surprisal: 7.46
# Token: riegel
#   Surprisal: 26.14
# Token: Im
#   Surprisal: 18.80
# Token: Wald
#   Surprisal: 9.58
# Token: singen
#   Surprisal: 13.66
# Token: die
#   Surprisal: 2.01
# Token: Vögel
#   Surprisal: 5.78
# Token: fröhlich
#   Surprisal: 9.86
# Token: ihr
#   Surprisal: 7.20
# Token: Lied
#   Surprisal: 0.79
# Token: riegel
#   Surprisal: 28.51
# Token: Der
#   Surprisal: 18.26
# Token: Detektiv
#   Surprisal: 16.20
# Token: löste
#   Surprisal: 12.41
# Token: das
#   Surprisal: 4.31
# Token: Rätsel
#   Surprisal: 1.78
# Token: um
#   Surprisal: 2.54
# Token: das
#   Surprisal: 3.51
# Token: gest
#   Surprisal: 7.93
# Token: ohlene
#   Surprisal: 0.02
# Token: Gemälde
#   Surprisal: 7.45
# Token: riegel
#   Surprisal: 24.81
# Token: Ein
#   Surprisal: 18.19
# Token: ungewöhn
#   Surprisal: 12.34
# Token: liches
#   Surprisal: 1.88
# Token: Geräusch
#   Surprisal: 9.52
# Token: ließ
#   Surprisal: 10.07
# Token: sie
#   Surprisal: 5.49
# Token: inneh
#   Surprisal: 13.47
# Token: alten
#   Surprisal: 0.01
# Token: und
#   Surprisal: 3.26
# Token: lau
#   Surprisal: 8.70
# Token: schen
#   Surprisal: 1.99
# Token: riegel
#   Surprisal: 34.34
# Token: Das
#   Surprisal: 18.88
# Token: neue
#   Surprisal: 7.30
# Token: Restaurant
#   Surprisal: 9.75
# Token: hat
#   Surprisal: 6.61
# Token: eine
#   Surprisal: 4.06
# Token: interessante
#   Surprisal: 8.95
# Token: Speise
#   Surprisal: 6.64
# Token: karte
#   Surprisal: 0.01
# Token: riegel
#   Surprisal: 29.94
# Token: Die
#   Surprisal: 17.84
# Token: geheimnis
#   Surprisal: 15.07
# Token: volle
#   Surprisal: 0.67
# Token: Atmosphäre
#   Surprisal: 9.29
# Token: der
#   Surprisal: 2.88
# Token: Gasse
#   Surprisal: 12.41
# Token: weckt
#   Surprisal: 12.34
# Token: die
#   Surprisal: 4.11
# Token: Neugier
#   Surprisal: 3.21
# Token: de
#   Surprisal: 2.69
# Token: riegel
#   Surprisal: 29.25
# Token: Der
#   Surprisal: 18.26
# Token: Gärtner
#   Surprisal: 14.55
# Token: pflanz
#   Surprisal: 12.80
# Token: te
#   Surprisal: 2.07
# Token: bunte
#   Surprisal: 11.59
# Token: Blumen
#   Surprisal: 3.38
# Token: in
#   Surprisal: 3.68
# Token: die
#   Surprisal: 2.65
# Token: Be
#   Surprisal: 8.64
# Token: ete
#   Surprisal: 0.03
# Token: riegel
#   Surprisal: 30.70
# Token: Der
#   Surprisal: 18.26
# Token: Regen
#   Surprisal: 11.33
# Token: kl
#   Surprisal: 11.05
# Token: opft
#   Surprisal: 3.61
# Token: leise
#   Surprisal: 8.80
# Token: an
#   Surprisal: 2.11
# Token: das
#   Surprisal: 6.45
# Token: Fenster
#   Surprisal: 1.98
# Token: riegel
#   Surprisal: 16.55
# Token: Ein
#   Surprisal: 18.19
# Token: Blick
#   Surprisal: 8.93
# Token: in
#   Surprisal: 1.47
# Token: die
#   Surprisal: 0.84
# Token: Astronomie
#   Surprisal: 16.80
# Token: enthüllt
#   Surprisal: 11.86
# Token: die
#   Surprisal: 2.79
# Token: Geheimnisse
#   Surprisal: 4.19
# Token: des
#   Surprisal: 1.93
# Token: Universums
#   Surprisal: 2.00
# Token: riegel
#   Surprisal: 27.16
# Token: Der
#   Surprisal: 18.26
# Token: Vertrags
#   Surprisal: 15.87
# Token: abschluss
#   Surprisal: 1.42
# Token: sah
#   Surprisal: 13.58
# Token: eine
#   Surprisal: 3.61
# Token: viel
#   Surprisal: 13.35
# Token: jährige
#   Surprisal: 5.12
# Token: Laufzeit
#   Surprisal: 4.01
# Token: vor
#   Surprisal: 3.01
# Token: riegel
#   Surprisal: 30.29
# Token: Beim
#   Surprisal: 23.09
# Token: Morgen
#   Surprisal: 12.09
# Token: sp
#   Surprisal: 5.12
# Token: azier
#   Surprisal: 0.01
# Token: gang
#   Surprisal: 0.01
# Token: fand
#   Surprisal: 10.48
# Token: ich
#   Surprisal: 2.46
# Token: eine
#   Surprisal: 4.34
# Token: verlorene
#   Surprisal: 13.64
# Token: Schatz
#   Surprisal: 7.89
# Token: karte
#   Surprisal: 2.11
# Token: riegel
#   Surprisal: 30.57
# Token: Das
#   Surprisal: 18.88
# Token: historische
#   Surprisal: 11.46
# Token: Fachwerk
#   Surprisal: 7.49
# Token: haus
#   Surprisal: 0.78
# Token: strahlt
#   Surprisal: 12.19
# Token: einen
#   Surprisal: 7.03
# Token: n
#   Surprisal: 9.81
# Token: ostal
#   Surprisal: 0.39
# Token: gischen
#   Surprisal: 0.14
# Token: Charme
#   Surprisal: 0.26
# Token: aus
#   Surprisal: 0.04
# Token: riegel
#   Surprisal: 37.51
# Token: Ein
#   Surprisal: 18.19
# Token: harmon
#   Surprisal: 13.26
# Token: ischer
#   Surprisal: 1.85
# Token: Klang
#   Surprisal: 3.44
# Token: te
#   Surprisal: 5.55
# Token: ppich
#   Surprisal: 0.01
# Token: um
#   Surprisal: 7.38
# Token: hü
#   Surprisal: 8.15
# Token: llt
#   Surprisal: 0.26
# Token: die
#   Surprisal: 1.86
# Token: Zuhörer
#   Surprisal: 6.18
# Token: im
#   Surprisal: 4.34
# Token: Konzerts
#   Surprisal: 5.92
# Token: aal
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 26.72
# Token: Das
#   Surprisal: 18.88
# Token: Haus
#   Surprisal: 7.61
# Token: neben
#   Surprisal: 9.93
# Token: dem
#   Surprisal: 1.23
# Token: Leuchtturm
#   Surprisal: 12.11
# Token: dient
#   Surprisal: 10.90
# Token: seit
#   Surprisal: 3.09
# Token: Jahren
#   Surprisal: 4.88
# Token: als
#   Surprisal: 0.32
# Token: Unterschl
#   Surprisal: 10.25
# Token: upf
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 26.50
# Token: Ein
#   Surprisal: 18.19
# Token: verloren
#   Surprisal: 12.97
# Token: er
#   Surprisal: 0.80
# Token: Schlüssel
#   Surprisal: 6.71
# Token: öffnet
#   Surprisal: 10.03
# Token: Türen
#   Surprisal: 9.00
# Token: zu
#   Surprisal: 6.06
# Token: unbekannten
#   Surprisal: 7.48
# Token: Welten
#   Surprisal: 3.90
# Token: riegel
#   Surprisal: 25.49
# Token: Ihre
#   Surprisal: 22.23
# Token: Augen
#   Surprisal: 10.20
# Token: spiegel
#   Surprisal: 19.14
# Token: ten
#   Surprisal: 0.13
# Token: die
#   Surprisal: 2.56
# Token: Ab
#   Surprisal: 9.16
# Token: gründe
#   Surprisal: 1.23
# Token: der
#   Surprisal: 1.79
# Token: vergangenen
#   Surprisal: 8.00
# Token: Jahre
#   Surprisal: 3.42
# Token: riegel
#   Surprisal: 29.75
# Token: Der
#   Surprisal: 18.26
# Token: alte
#   Surprisal: 10.05
# Token: Schrank
#   Surprisal: 11.65
# Token: versteckte
#   Surprisal: 15.67
# Token: ein
#   Surprisal: 6.22
# Token: geheimnis
#   Surprisal: 10.58
# Token: volles
#   Surprisal: 0.13
# Token: Tagebuch
#   Surprisal: 6.65
# Token: riegel
#   Surprisal: 22.74
# Token: Die
#   Surprisal: 17.84
# Token: Wirtschafts
#   Surprisal: 10.85
# Token: daten
#   Surprisal: 6.60
# Token: deuten
#   Surprisal: 6.08
# Token: auf
#   Surprisal: 2.11
# Token: ein
#   Surprisal: 3.18
# Token: langsam
#   Surprisal: 6.78
# Token: es
#   Surprisal: 0.81
# Token: Wachstum
#   Surprisal: 0.87
# Token: hin
#   Surprisal: 1.41
# Token: riegel
#   Surprisal: 31.86
# Token: Der
#   Surprisal: 18.26
# Token: tanz
#   Surprisal: 16.67
# Token: ende
#   Surprisal: 1.01
# Token: Schmetterling
#   Surprisal: 9.29
# Token: verz
#   Surprisal: 13.09
# Token: aubert
#   Surprisal: 0.80
# Token: mit
#   Surprisal: 4.02
# Token: seinen
#   Surprisal: 3.11
# Token: bunten
#   Surprisal: 4.32
# Token: Flügeln
#   Surprisal: 4.40
# Token: riegel
#   Surprisal: 28.81
# Token: Die
#   Surprisal: 17.84
# Token: kl
#   Surprisal: 13.24
# Token: irren
#   Surprisal: 4.62
# Token: de
#   Surprisal: 0.19
# Token: Kälte
#   Surprisal: 0.57
# Token: lässt
#   Surprisal: 5.92
# Token: die
#   Surprisal: 2.33
# Token: Seen
#   Surprisal: 10.47
# Token: im
#   Surprisal: 3.33
# Token: Winter
#   Surprisal: 6.35
# Token: zuf
#   Surprisal: 10.27
# Token: r
#   Surprisal: 0.08
# Token: ieren
#   Surprisal: 0.01
# Token: riegel
#   Surprisal: 28.65
# Token: Die
#   Surprisal: 17.84
# Token: Bibliothek
#   Surprisal: 12.89
# Token: arin
#   Surprisal: 5.83
# Token: verschl
#   Surprisal: 16.68
# Token: uck
#   Surprisal: 5.50
# Token: te
#   Surprisal: 0.01
# Token: versehentlich
#   Surprisal: 9.09
# Token: einen
#   Surprisal: 3.69
# Token: Buchstaben
#   Surprisal: 9.40
# Token:
#   Surprisal: 13.21
# Token: riegel
#   Surprisal: 18.32
# Token: Die
#   Surprisal: 17.84
# Token: Verkehrs
#   Surprisal: 12.03
# Token: lage
#   Surprisal: 5.73
# Token: ist
#   Surprisal: 3.83
# Token: heute
#   Surprisal: 6.88
# Token: morgen
#   Surprisal: 6.61
# Token: ziemlich
#   Surprisal: 4.87
# Token: entspannt
#   Surprisal: 4.75
# Token: riegel
#   Surprisal: 31.34
# Token: Während
#   Surprisal: 22.17
# Token: des
#   Surprisal: 2.58
# Token: Telefon
#   Surprisal: 10.99
# Token: ats
#   Surprisal: 0.31
# Token: hörte
#   Surprisal: 8.48
# Token: sie
#   Surprisal: 2.95
# Token: das
#   Surprisal: 5.78
# Token: Meer
#   Surprisal: 11.84
# Token: ra
#   Surprisal: 8.41
# Token: uschen
#   Surprisal: 0.05
# Token: riegel
#   Surprisal: 31.83
# Token: Ein
#   Surprisal: 18.19
# Token: war
#   Surprisal: 12.64
# Token: mes
#   Surprisal: 6.03
# Token: Lächeln
#   Surprisal: 7.40
# Token: z
#   Surprisal: 7.67
# Token: aubert
#   Surprisal: 3.27
# Token: Sonnenschein
#   Surprisal: 13.08
# Token: in
#   Surprisal: 3.20
# Token: graue
#   Surprisal: 14.20
# Token: Tage
#   Surprisal: 7.64
# Token: riegel
#   Surprisal: 26.52
# Token: Die
#   Surprisal: 17.84
# Token: Ent
#   Surprisal: 11.36
# Token: schlüsselung
#   Surprisal: 8.51
# Token: des
#   Surprisal: 1.99
# Token: menschlichen
#   Surprisal: 6.87
# Token: Gen
#   Surprisal: 1.67
# Token: oms
#   Surprisal: 0.03
# Token: wirft
#   Surprisal: 11.08
# Token: eth
#   Surprisal: 7.75
# Token: ische
#   Surprisal: 0.10
# Token: Fragen
#   Surprisal: 0.87
# Token: auf
#   Surprisal: 0.11
# Token: riegel
#   Surprisal: 32.19
# Token: Der
#   Surprisal: 18.26
# Token: S
#   Surprisal: 9.29
# Token: eilt
#   Surprisal: 9.95
# Token: änzer
#   Surprisal: 4.42
# Token: b
#   Surprisal: 11.00
# Token: ackt
#   Surprisal: 4.77
# Token: Kek
#   Surprisal: 8.25
# Token: se
#   Surprisal: 0.05
# Token: in
#   Surprisal: 4.31
# Token: der
#   Surprisal: 2.82
# Token: Hänge
#   Surprisal: 9.03
# Token: m
#   Surprisal: 0.03
# Token: atte
#   Surprisal: 0.00
# Token: riegel
#   Surprisal: 26.83
# Token: Die
#   Surprisal: 17.84
# Token: ei
#   Surprisal: 13.19
# Token: f
#   Surprisal: 7.84
# Token: rigen
#   Surprisal: 9.59
# Token: Bienen
#   Surprisal: 8.12
# Token: schw
#   Surprisal: 11.11
# Token: är
#   Surprisal: 0.13
# Token: me
#   Surprisal: 0.29
# Token: best
#   Surprisal: 11.15
# Token: äu
#   Surprisal: 0.31
# Token: ben
#   Surprisal: 0.03
# Token: em
#   Surprisal: 15.06
# Token: sig
#   Surprisal: 3.36
# Token: die
#   Surprisal: 2.18
# Token: d
#   Surprisal: 11.30
# Token: uften
#   Surprisal: 0.24
# Token: den
#   Surprisal: 0.15
# Token: Blüten
#   Surprisal: 2.16
# Token: riegel
#   Surprisal: 17.85
# Token: Der
#   Surprisal: 18.26
# Token: Brie
#   Surprisal: 13.44
# Token: ft
#   Surprisal: 0.57
# Token: räger
#   Surprisal: 1.12
# Token: bringt
#   Surprisal: 8.29
# Token: täglich
#   Surprisal: 8.40
# Token: die
#   Surprisal: 4.44
# Token: Post
#   Surprisal: 2.25
# Token: vorbei
#   Surprisal: 8.02
# Token: riegel
#   Surprisal: 30.80
# Token: Ein
#   Surprisal: 18.19
# Token: Flü
#   Surprisal: 16.02
# Token: stern
#   Surprisal: 2.60
# Token: durch
#   Surprisal: 8.92
# Token: zog
#   Surprisal: 10.86
# Token: den
#   Surprisal: 2.82
# Token: verw
#   Surprisal: 14.13
# Token: un
#   Surprisal: 3.85
# Token: schen
#   Surprisal: 0.30
# Token: en
#   Surprisal: 0.05
# Token: Wald
#   Surprisal: 2.42
# Token: im
#   Surprisal: 6.59
# Token: Mond
#   Surprisal: 9.90
# Token: schein
#   Surprisal: 0.99
# Token: riegel
#   Surprisal: 22.92
# Token: In
#   Surprisal: 16.59
# Token: der
#   Surprisal: 5.12
# Token: Stadt
#   Surprisal: 6.59
# Token: herrscht
#   Surprisal: 10.52
# Token: re
#   Surprisal: 5.29
# Token: ges
#   Surprisal: 1.44
# Token: Treiben
#   Surprisal: 0.41
# Token: am
#   Surprisal: 6.98
# Token: Samstag
#   Surprisal: 4.52
# Token: riegel
#   Surprisal: 29.93
# Token: Auf
#   Surprisal: 20.57
# Token: dem
#   Surprisal: 3.50
# Token: Flo
#   Surprisal: 11.32
# Token: hmarkt
#   Surprisal: 0.04
# Token: entdeckte
#   Surprisal: 11.34
# Token: ich
#   Surprisal: 1.98
# Token: einen
#   Surprisal: 3.87
# Token: antiken
#   Surprisal: 11.87
# Token: Spiegel
#   Surprisal: 7.56
# Token: riegel
#   Surprisal: 16.05
# Token: Der
#   Surprisal: 18.26
# Token: präch
#   Surprisal: 14.62
# Token: tige
#   Surprisal: 0.25
# Token: Regenbogen
#   Surprisal: 11.94
# Token: erst
#   Surprisal: 11.36
# Token: ra
#   Surprisal: 0.05
# Token: hlt
#   Surprisal: 0.13
# Token: nach
#   Surprisal: 6.85
# Token: dem
#   Surprisal: 2.04
# Token: heftigen
#   Surprisal: 8.79
# Token: Gewitter
#   Surprisal: 1.59
# Token: riegel
#   Surprisal: 23.14
# Token: Über
#   Surprisal: 20.36
# Token: den
#   Surprisal: 6.68
# Token: D
#   Surprisal: 7.10
# Token: ächern
#   Surprisal: 0.45
# Token: der
#   Surprisal: 1.78
# Token: Stadt
#   Surprisal: 1.02
# Token: verliert
#   Surprisal: 15.39
# Token: sich
#   Surprisal: 1.20
# Token: der
#   Surprisal: 2.37
# Token: Horizont
#   Surprisal: 9.50
# Token: riegel
#   Surprisal: 24.67
# Token: In
#   Surprisal: 16.59
# Token: der
#   Surprisal: 5.12
# Token: alten
#   Surprisal: 9.99
# Token: Buchhandlung
#   Surprisal: 13.42
# Token: fand
#   Surprisal: 10.67
# Token: ich
#   Surprisal: 3.66
# Token: ein
#   Surprisal: 4.55
# Token: Buch
#   Surprisal: 3.29
# Token: ohne
#   Surprisal: 9.74
# Token: Titel
#   Surprisal: 2.34
# Token: riegel
#   Surprisal: 20.22
# Token: Der
#   Surprisal: 18.26
# Token: Kur
#   Surprisal: 12.53
# Token: steilnehmer
#   Surprisal: 9.59
# Token: wählt
#   Surprisal: 9.38
# Token: das
#   Surprisal: 4.45
# Token: einfachste
#   Surprisal: 10.44
# Token: Exemplar
#   Surprisal: 8.63
# Token: der
#   Surprisal: 4.72
# Token: verg
#   Surprisal: 13.38
# Token: il
#   Surprisal: 3.52
# Token: bten
#   Surprisal: 0.11
# Token: Schrift
#   Surprisal: 5.91
# Token: stücke
#   Surprisal: 3.68
# Token: riegel
#   Surprisal: 31.27
# /tmp/ipykernel_3730/4104884538.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surprisal_df_filt['surprisal_new']= np.where(surprisal_df_filt['word_order'] == 1, np.nan, surprisal_df_filt['surprisal'])
