# %%
import mne 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy

# %%
#Load unshuffled acc
subjects = ['sub05','sub06', 'sub07', 'sub08','sub09','sub10','sub11','sub12','sub13','sub14','sub15','sub16',
'sub18','sub19','sub20','sub21','sub22','sub23', 'sub25', 'sub26', 'sub27', 'sub28', 'sub29', 'sub30', 
'sub31', 'sub32', 'sub33', 'sub34', 'sub35', 'sub36', 'sub37', 'sub38', 'sub39', 'sub40', 'sub41', 'sub42', 'sub43', 
'sub44', 'sub45', 'sub46', 'sub47', 'sub48', 'sub49', 'sub50', 'sub51', 'sub52', 'sub53', 'sub55', 'sub56', 
'sub57', 'sub58', 'sub59', 'sub60', 'sub61', 'sub62',  
'sub64', 'sub65', 'sub66', 'sub67', 'sub68', 'sub69', 'sub70', 'sub72']



acctr = []
for subject in subjects:
    print(subject)
    acc_unshuff = pd.read_csv("../trf_results/{s}/fits_linguistic_{s}_within_nb_stan_notr.csv".format(s=subject))
    acc_unshuff = acc_unshuff[acc_unshuff['window'] == "none"]




    
    acc_shuff = []
    feats = [ 'ling_word_target']

    #Load shuffled acc
    for feat in feats:
        
        shuff = pd.read_csv("../trf_results/{s}/shuffle/fits_linguistic_{s}_mean599_{f}_within_nb_stan_notr.csv".format(s = subject, i = it, f = feat))

     
        shuff['feat'] = feat
        shuff['subject'] = subject
        shuff = shuff[shuff['window'] == "none"]
        acc_shuff.append(shuff)
    
    acc_shuff = pd.concat(acc_shuff)
    
    acc_shuff = acc_shuff.groupby(['trialnum', 'channel','feature_shuffle', 'subject'], as_index = False, sort = False).mean('fit')              
    acc_shuff['feature'] = acc_shuff['feature_shuffle']
    
    #Merge 
    accmere = pd.merge(acc_unshuff, acc_shuff, on = ['subject', 'trialnum', 'channel'])
    accmere['correlation'] = accmere['fit_x'] - accmere['fit_y'] 

    acctr.append(accmere)
# Out:
# sub05
# sub06
# sub07
# sub08
# sub09
# sub10
# sub11
# sub12
# sub13
# sub14
# sub15
# sub16
# sub18
# sub19
# sub20
# sub21
# sub22
# sub23
# sub25
# sub26
# sub27
# sub28
# sub29
# sub30
# sub31
# sub32
# sub33
# sub34
# sub35
# sub36
# sub37
# sub38
# sub39
# sub40
# sub41
# sub42
# sub43
# sub44
# sub45
# sub46
# sub47
# sub48
# sub49
# sub50
# sub51
# sub52
# sub53
# sub55
# sub56
# sub57
# sub58
# sub59
# sub60
# sub61
# sub62
# sub64
# sub65
# sub66
# sub67
# sub68
# sub69
# sub70
# sub72

# %%
acctr = pd.concat(acctr)
dfl=acctr.copy()
dfl = dfl.groupby(['subject', 'channel', 'feature_shuffle'], as_index = False, sort = False).mean('correlation')

# %%
dfl['feat'] = dfl['feature_shuffle']

# %%
# %run plotting_functions_within.ipynb

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as clr
import copy

cluster_dict = {}

feats = dfl['feat'].unique()

for feat in feats:
    plot_fits_clusters(feat)
    
    sname = "../figures/" + feat  + "_topo_within_newf0.svg"
    
    plt.savefig(sname, bbox_inches = "tight")
# Out:
# Could not find a adjacency matrix for the data. Computing adjacency based on Delaunay triangulations.
# -- number of adjacent vertices : 61
# Clustering.
# stat_fun(H1): min=0.6009659954263216 max=3.7224726747475514
# Running initial clustering …
# Using 19 thresholds from 0.00 to 3.60 for TFCE computation (h_power=2.00, e_power=0.50)
# Found 61 clusters
#   0%|          | Permuting : 0/1023 [00:00<?,       ?it/s]
# (array([[2.11774715, 1.83774715, 1.54380838, 0.93722996, 2.37387212,
#         3.64783818, 3.0415889 , 3.2415889 , 2.8299288 , 2.60365463,
#         2.8299288 , 3.89600565, 3.54985859, 3.89600565, 3.41129453,
#         2.8299288 , 3.41129453, 3.54985859, 3.54985859, 3.2415889 ,
#         3.0415889 , 2.8299288 , 2.37387212, 2.11774715, 2.41387212,
#         2.15774715, 1.24447579, 3.41129453, 3.2415889 , 3.2415889 ,
#         2.37387212, 2.11774715, 1.83774715, 3.58985859, 2.11774715,
#         1.83774715, 2.45387212, 1.24447579, 2.37387212, 3.0415889 ,
#         3.2415889 , 2.37387212, 2.11774715, 3.82672362, 3.62985859,
#         3.89600565, 3.41129453, 3.2415889 , 3.2415889 , 1.24447579,
#         2.11774715, 3.82672362, 3.41129453, 2.37387212, 2.11774715,
#         3.41129453, 3.54985859, 1.83774715, 1.54380838, 0.93722996,
#         1.83774715]]), [(array([0]), array([0])), (array([0]), array([1])), (array([0]), array([2])), (array([0]), array([3])), (array([0]), array([4])), (array([0]), array([5])), (array([0]), array([6])), (array([0]), array([7])), (array([0]), array([8])), (array([0]), array([9])), (array([0]), array([10])), (array([0]), array([11])), (array([0]), array([12])), (array([0]), array([13])), (array([0]), array([14])), (array([0]), array([15])), (array([0]), array([16])), (array([0]), array([17])), (array([0]), array([18])), (array([0]), array([19])), (array([0]), array([20])), (array([0]), array([21])), (array([0]), array([22])), (array([0]), array([23])), (array([0]), array([24])), (array([0]), array([25])), (array([0]), array([26])), (array([0]), array([27])), (array([0]), array([28])), (array([0]), array([29])), (array([0]), array([30])), (array([0]), array([31])), (array([0]), array([32])), (array([0]), array([33])), (array([0]), array([34])), (array([0]), array([35])), (array([0]), array([36])), (array([0]), array([37])), (array([0]), array([38])), (array([0]), array([39])), (array([0]), array([40])), (array([0]), array([41])), (array([0]), array([42])), (array([0]), array([43])), (array([0]), array([44])), (array([0]), array([45])), (array([0]), array([46])), (array([0]), array([47])), (array([0]), array([48])), (array([0]), array([49])), (array([0]), array([50])), (array([0]), array([51])), (array([0]), array([52])), (array([0]), array([53])), (array([0]), array([54])), (array([0]), array([55])), (array([0]), array([56])), (array([0]), array([57])), (array([0]), array([58])), (array([0]), array([59])), (array([0]), array([60]))], array([0.07324219, 0.11035156, 0.1796875 , 0.41894531, 0.04199219,
#        0.00292969, 0.00683594, 0.00488281, 0.01269531, 0.02539062,
#        0.01269531, 0.00195312, 0.00292969, 0.00195312, 0.00292969,
#        0.01269531, 0.00292969, 0.00292969, 0.00292969, 0.00488281,
#        0.00683594, 0.01269531, 0.04199219, 0.07324219, 0.04003906,
#        0.06835938, 0.27148438, 0.00292969, 0.00488281, 0.00488281,
#        0.04199219, 0.07324219, 0.11035156, 0.00292969, 0.07324219,
#        0.11035156, 0.03808594, 0.27148438, 0.04199219, 0.00683594,
#        0.00488281, 0.04199219, 0.07324219, 0.00195312, 0.00292969,
#        0.00195312, 0.00292969, 0.00488281, 0.00488281, 0.27148438,
#        0.07324219, 0.00195312, 0.00292969, 0.04199219, 0.07324219,
#        0.00292969, 0.00292969, 0.11035156, 0.1796875 , 0.41894531,
#        0.11035156]), array([3.89600565, 0.11313708, 1.06228094, ..., 0.72332499, 1.75365019,
#        0.71232189]))
# 61

# %%
sdf = acctr.groupby(['subject', 'feature_shuffle', 'trialnum'], as_index = False, sort = False).mean(['correlation'])
sdf = sdf[['subject', 'feature_shuffle', 'trialnum', 'correlation']]
sdf.to_csv('../statistics/fits_ling_within.csv')
